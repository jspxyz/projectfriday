# %%
'''
Creating to run Model D Conv1d_mfcc40
different layer system
full mfcc 40 features
Created on 2020.12.11
Label: Polarity

'''
# libraries
import numpy as np
import pandas as pd
import pickle
import seaborn as sns
import tensorflow as tf

from tensorflow.keras.layers import Dense, Dropout, Flatten, Input
from tensorflow.keras.layers import Activation, BatchNormalization
from tensorflow.keras.layers import Conv1D, Conv2D, LSTM
from tensorflow.keras.layers import AveragePooling1D, GlobalAveragePooling2D, MaxPooling1D
from tensorflow.keras.models import Model, model_from_json, Sequential

# added this to plot
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
# load datasets

# assigning the pickle files
with open('./Data_Array_Storage/X_train_mfcc40_axis0_pol.pkl', 'rb') as f:
    X_train = pickle.load(f)

with open('./Data_Array_Storage/X_test_mfcc40_axis0_pol.pkl', 'rb') as f:
    X_test = pickle.load(f)

with open('./Data_Array_Storage/y_train_mfcc40_axis0_pol.pkl', 'rb') as f:
    y_train = pickle.load(f)

with open('./Data_Array_Storage/y_test_mfcc40_axis0_pol.pkl', 'rb') as f:
    y_test = pickle.load(f)
    
print('dataset loaded')
# Out:
# dataset loaded

# %%
# input shape
input_shape = (X_train.shape[1], X_train.shape[2])
print(input_shape)
# Out:
# (216, 40)

# %%
def model_d_conv1d(input_shape):
    model = Sequential()
    model.add(Conv1D(32, 3, padding='same',input_shape=input_shape))  # X_train.shape[1] = No. of Columns (216)
    model.add(Activation('relu'))
    model.add(Conv1D(32, 3, padding='same'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.25))
    model.add(MaxPooling1D(pool_size=(3)))
    model.add(Conv1D(64, 3, padding='same'))
    model.add(Activation('relu'))
    model.add(Conv1D(64, 3, padding='same'))
    model.add(Dropout(0.25))
    model.add(MaxPooling1D(pool_size=(3))) # added drop out and maxpooling layer on 20201209 at 1330
    model.add(Activation('relu'))
    model.add(Conv1D(64, 3, padding='same'))
    model.add(Activation('relu'))
    model.add(Conv1D(64, 3, padding='same'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.25))
    model.add(MaxPooling1D(pool_size=(3)))
    model.add(Conv1D(128, 3, padding='same'))
    model.add(Activation('relu'))
    model.add(Conv1D(128, 3, padding='same'))
    model.add(Activation('relu'))
    model.add(Conv1D(256, 3, padding='same'))
    model.add(Activation('relu'))
#     model.add(LSTM(64))
    model.add(Flatten())
    model.add(Dense(3)) # Target class number
    model.add(Activation('softmax'))
    
    # model optimizer
#     model = model_d_conv1d(input_shape)
    optimizer = tf.keras.optimizers.RMSprop(lr=0.000001, decay=1e-6)
    
    # compile model
    model.compile(loss='categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])

    return model

# %%
def model_d_conv1d_flip(input_shape):
    model = Sequential()
    model.add(Conv1D(256, 3, padding='same',input_shape=input_shape))  # X_train.shape[1] = No. of Columns (216)
    model.add(Activation('relu'))
    model.add(Conv1D(256, 3, padding='same'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.25))
    model.add(MaxPooling1D(pool_size=(3)))
    model.add(Conv1D(128, 3, padding='same'))
    model.add(Activation('relu'))
    model.add(Conv1D(128, 3, padding='same'))
    model.add(Dropout(0.25))
    model.add(MaxPooling1D(pool_size=(3))) # added drop out and maxpooling layer on 20201209 at 1330
    model.add(Activation('relu'))
    model.add(Conv1D(128, 3, padding='same'))
    model.add(Activation('relu'))
    model.add(Conv1D(128, 3, padding='same'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.25))
    model.add(MaxPooling1D(pool_size=(3)))
    model.add(Conv1D(64, 3, padding='same'))
    model.add(Activation('relu'))
    model.add(Conv1D(64, 3, padding='same'))
    model.add(Activation('relu'))
    model.add(Conv1D(32, 3, padding='same'))
    model.add(Activation('relu'))
    model.add(Flatten())
    model.add(Dense(3)) # Target class number
    model.add(Activation('softmax'))
    
    # model optimizer
#     model = model_d_conv1d(input_shape)
    optimizer = tf.keras.optimizers.RMSprop(lr=0.000001, decay=1e-6)
    
    # compile model
    model.compile(loss='categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])

    return model

# %%
# load model and input shape
# from models import model_d_conv1d

# model = model_d_conv1d_flip(input_shape)
model = model_d_conv1d(input_shape)
# optimizer = tf.keras.optimizers.RMSprop(lr=0.000001, decay=1e-6)

print('input shape, model, optimizer loaded')

model.summary()
# Out:
# input shape, model, optimizer loaded
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 216, 32)           3872
# _________________________________________________________________
# activation (Activation)      (None, 216, 32)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 216, 32)           3104
# _________________________________________________________________
# batch_normalization (BatchNo (None, 216, 32)           128
# _________________________________________________________________
# activation_1 (Activation)    (None, 216, 32)           0
# _________________________________________________________________
# dropout (Dropout)            (None, 216, 32)           0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 72, 32)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 72, 64)            6208
# _________________________________________________________________
# activation_2 (Activation)    (None, 72, 64)            0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 72, 64)            12352
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 72, 64)            0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 24, 64)            0
# _________________________________________________________________
# activation_3 (Activation)    (None, 24, 64)            0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 24, 64)            12352
# _________________________________________________________________
# activation_4 (Activation)    (None, 24, 64)            0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 24, 64)            12352
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 24, 64)            256
# _________________________________________________________________
# activation_5 (Activation)    (None, 24, 64)            0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 24, 64)            0
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 8, 64)             0
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 8, 128)            24704
# _________________________________________________________________
# activation_6 (Activation)    (None, 8, 128)            0
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 8, 128)            49280
# _________________________________________________________________
# activation_7 (Activation)    (None, 8, 128)            0
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, 8, 256)            98560
# _________________________________________________________________
# activation_8 (Activation)    (None, 8, 256)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 3)                 6147
# _________________________________________________________________
# activation_9 (Activation)    (None, 3)                 0
# =================================================================
# Total params: 229,315
# Trainable params: 229,123
# Non-trainable params: 192
# _________________________________________________________________

# %%
# callback list: ModelCheckpoint, reduceLROnPlat, EarlyStopping
# checkpoint_path = "./models_saved/model_d_conv1d_v3.h5"

checkpoint_path = "./models_saved/model_d_conv1d_mfcc40_pol.h5"

# Create a callback that saves the model's weights
callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=False,
                                                 save_best_only=True,
                                                 verbose=1), # 1 tells your which epoch is saving
#                                                  monitor='val_categorical_accuracy',  # added for emo1d
#                                                  mode='max'), # added for emo1d
               tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', # changed from 'val_accuracy', 'val_loss'
                                                patience=5, 
                                                restore_best_weights=True),
#                                                 verbose = 1, # added verbose for emo1d
#                                                 mode = 'min'), # added for emo1d
               tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', 
                                                    patience=2, 
                                                    factor=0.5, 
                                                    min_lr=0.000001, 
                                                    verbose=1)]

print('callbacks and checkpoints set')
# Out:
# callbacks and checkpoints set

# %%
batch_size = 16

model_history=model.fit(X_train, 
                        y_train,
                        batch_size=batch_size,
                        epochs=150,
                        validation_data=(X_test, y_test),
                        verbose=2,
                        callbacks=callbacks)
# Out:
# Epoch 1/150
#
# Epoch 00001: val_loss improved from inf to 0.92260, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 31s - loss: 0.9184 - accuracy: 0.6311 - val_loss: 0.9226 - val_accuracy: 0.6310
# Epoch 2/150
#
# Epoch 00002: val_loss improved from 0.92260 to 0.91075, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 33s - loss: 0.8883 - accuracy: 0.6331 - val_loss: 0.9108 - val_accuracy: 0.6310
# Epoch 3/150
#
# Epoch 00003: val_loss improved from 0.91075 to 0.90150, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 29s - loss: 0.8743 - accuracy: 0.6366 - val_loss: 0.9015 - val_accuracy: 0.6312
# Epoch 4/150
#
# Epoch 00004: val_loss improved from 0.90150 to 0.89338, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 29s - loss: 0.8609 - accuracy: 0.6417 - val_loss: 0.8934 - val_accuracy: 0.6310
# Epoch 5/150
#
# Epoch 00005: val_loss improved from 0.89338 to 0.88645, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 30s - loss: 0.8527 - accuracy: 0.6475 - val_loss: 0.8864 - val_accuracy: 0.6321
# Epoch 6/150
#
# Epoch 00006: val_loss improved from 0.88645 to 0.87927, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 30s - loss: 0.8428 - accuracy: 0.6541 - val_loss: 0.8793 - val_accuracy: 0.6331
# Epoch 7/150
#
# Epoch 00007: val_loss improved from 0.87927 to 0.87312, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 33s - loss: 0.8317 - accuracy: 0.6621 - val_loss: 0.8731 - val_accuracy: 0.6341
# Epoch 8/150
#
# Epoch 00008: val_loss improved from 0.87312 to 0.86667, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 31s - loss: 0.8248 - accuracy: 0.6626 - val_loss: 0.8667 - val_accuracy: 0.6362
# Epoch 9/150
#
# Epoch 00009: val_loss improved from 0.86667 to 0.86406, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 30s - loss: 0.8170 - accuracy: 0.6659 - val_loss: 0.8641 - val_accuracy: 0.6376
# Epoch 10/150
#
# Epoch 00010: val_loss improved from 0.86406 to 0.85817, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 30s - loss: 0.8109 - accuracy: 0.6687 - val_loss: 0.8582 - val_accuracy: 0.6397
# Epoch 11/150
#
# Epoch 00011: val_loss improved from 0.85817 to 0.85351, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 29s - loss: 0.8033 - accuracy: 0.6709 - val_loss: 0.8535 - val_accuracy: 0.6419
# Epoch 12/150
#
# Epoch 00012: val_loss improved from 0.85351 to 0.84881, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 29s - loss: 0.7966 - accuracy: 0.6729 - val_loss: 0.8488 - val_accuracy: 0.6440
# Epoch 13/150
#
# Epoch 00013: val_loss improved from 0.84881 to 0.84756, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 31s - loss: 0.7925 - accuracy: 0.6723 - val_loss: 0.8476 - val_accuracy: 0.6493
# Epoch 14/150
#
# Epoch 00014: val_loss improved from 0.84756 to 0.84319, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 24s - loss: 0.7870 - accuracy: 0.6753 - val_loss: 0.8432 - val_accuracy: 0.6489
# Epoch 15/150
#
# Epoch 00015: val_loss improved from 0.84319 to 0.83988, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 23s - loss: 0.7803 - accuracy: 0.6769 - val_loss: 0.8399 - val_accuracy: 0.6499
# Epoch 16/150
#
# Epoch 00016: val_loss improved from 0.83988 to 0.83479, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 24s - loss: 0.7781 - accuracy: 0.6790 - val_loss: 0.8348 - val_accuracy: 0.6528
# Epoch 17/150
#
# Epoch 00017: val_loss improved from 0.83479 to 0.82951, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 22s - loss: 0.7727 - accuracy: 0.6828 - val_loss: 0.8295 - val_accuracy: 0.6547
# Epoch 18/150
#
# Epoch 00018: val_loss improved from 0.82951 to 0.82816, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 24s - loss: 0.7673 - accuracy: 0.6869 - val_loss: 0.8282 - val_accuracy: 0.6565
# Epoch 19/150
#
# Epoch 00019: val_loss improved from 0.82816 to 0.82513, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 26s - loss: 0.7654 - accuracy: 0.6852 - val_loss: 0.8251 - val_accuracy: 0.6582
# Epoch 20/150
#
# Epoch 00020: val_loss improved from 0.82513 to 0.82440, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 25s - loss: 0.7618 - accuracy: 0.6906 - val_loss: 0.8244 - val_accuracy: 0.6586
# Epoch 21/150
#
# Epoch 00021: val_loss improved from 0.82440 to 0.81830, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 23s - loss: 0.7583 - accuracy: 0.6939 - val_loss: 0.8183 - val_accuracy: 0.6621
# Epoch 22/150
#
# Epoch 00022: val_loss improved from 0.81830 to 0.81640, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 22s - loss: 0.7532 - accuracy: 0.6957 - val_loss: 0.8164 - val_accuracy: 0.6643
# Epoch 23/150
#
# Epoch 00023: val_loss improved from 0.81640 to 0.81388, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 22s - loss: 0.7510 - accuracy: 0.7001 - val_loss: 0.8139 - val_accuracy: 0.6662
# Epoch 24/150
#
# Epoch 00024: val_loss improved from 0.81388 to 0.80877, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 23s - loss: 0.7437 - accuracy: 0.7027 - val_loss: 0.8088 - val_accuracy: 0.6695
# Epoch 25/150
#
# Epoch 00025: val_loss improved from 0.80877 to 0.80751, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 23s - loss: 0.7443 - accuracy: 0.7030 - val_loss: 0.8075 - val_accuracy: 0.6711
# Epoch 26/150
#
# Epoch 00026: val_loss improved from 0.80751 to 0.80326, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 24s - loss: 0.7394 - accuracy: 0.7053 - val_loss: 0.8033 - val_accuracy: 0.6730
# Epoch 27/150
#
# Epoch 00027: val_loss improved from 0.80326 to 0.80000, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 24s - loss: 0.7344 - accuracy: 0.7065 - val_loss: 0.8000 - val_accuracy: 0.6738
# Epoch 28/150
#
# Epoch 00028: val_loss improved from 0.80000 to 0.79937, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 23s - loss: 0.7346 - accuracy: 0.7048 - val_loss: 0.7994 - val_accuracy: 0.6791
# Epoch 29/150
#
# Epoch 00029: val_loss did not improve from 0.79937
# 1217/1217 - 23s - loss: 0.7312 - accuracy: 0.7106 - val_loss: 0.8003 - val_accuracy: 0.6773
# Epoch 30/150
#
# Epoch 00030: val_loss improved from 0.79937 to 0.79497, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 22s - loss: 0.7283 - accuracy: 0.7102 - val_loss: 0.7950 - val_accuracy: 0.6824
# Epoch 31/150
#
# Epoch 00031: val_loss improved from 0.79497 to 0.79341, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 23s - loss: 0.7259 - accuracy: 0.7108 - val_loss: 0.7934 - val_accuracy: 0.6820
# Epoch 32/150
#
# Epoch 00032: val_loss improved from 0.79341 to 0.79004, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 23s - loss: 0.7218 - accuracy: 0.7097 - val_loss: 0.7900 - val_accuracy: 0.6849
# Epoch 33/150
#
# Epoch 00033: val_loss improved from 0.79004 to 0.78675, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 22s - loss: 0.7159 - accuracy: 0.7120 - val_loss: 0.7867 - val_accuracy: 0.6847
# Epoch 34/150
#
# Epoch 00034: val_loss improved from 0.78675 to 0.78508, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 23s - loss: 0.7152 - accuracy: 0.7137 - val_loss: 0.7851 - val_accuracy: 0.6876
# Epoch 35/150
#
# Epoch 00035: val_loss improved from 0.78508 to 0.77989, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 23s - loss: 0.7138 - accuracy: 0.7130 - val_loss: 0.7799 - val_accuracy: 0.6900
# Epoch 36/150
#
# Epoch 00036: val_loss did not improve from 0.77989
# 1217/1217 - 22s - loss: 0.7099 - accuracy: 0.7134 - val_loss: 0.7803 - val_accuracy: 0.6896
# Epoch 37/150
#
# Epoch 00037: val_loss improved from 0.77989 to 0.77830, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 23s - loss: 0.7047 - accuracy: 0.7167 - val_loss: 0.7783 - val_accuracy: 0.6915
# Epoch 38/150
#
# Epoch 00038: val_loss improved from 0.77830 to 0.77361, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 23s - loss: 0.7029 - accuracy: 0.7158 - val_loss: 0.7736 - val_accuracy: 0.6929
# Epoch 39/150
#
# Epoch 00039: val_loss did not improve from 0.77361
# 1217/1217 - 23s - loss: 0.7033 - accuracy: 0.7162 - val_loss: 0.7756 - val_accuracy: 0.6927
# Epoch 40/150
#
# Epoch 00040: val_loss improved from 0.77361 to 0.77197, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 23s - loss: 0.7011 - accuracy: 0.7154 - val_loss: 0.7720 - val_accuracy: 0.6954
# Epoch 41/150
#
# Epoch 00041: val_loss improved from 0.77197 to 0.77097, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 22s - loss: 0.6986 - accuracy: 0.7165 - val_loss: 0.7710 - val_accuracy: 0.6954
# Epoch 42/150
#
# Epoch 00042: val_loss improved from 0.77097 to 0.76859, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 22s - loss: 0.6967 - accuracy: 0.7187 - val_loss: 0.7686 - val_accuracy: 0.6958
# Epoch 43/150
#
# Epoch 00043: val_loss improved from 0.76859 to 0.76695, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 22s - loss: 0.6932 - accuracy: 0.7176 - val_loss: 0.7670 - val_accuracy: 0.6964
# Epoch 44/150
#
# Epoch 00044: val_loss did not improve from 0.76695
# 1217/1217 - 21s - loss: 0.6920 - accuracy: 0.7167 - val_loss: 0.7686 - val_accuracy: 0.6960
# Epoch 45/150
#
# Epoch 00045: val_loss improved from 0.76695 to 0.76466, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 22s - loss: 0.6892 - accuracy: 0.7170 - val_loss: 0.7647 - val_accuracy: 0.6954
# Epoch 46/150
#
# Epoch 00046: val_loss improved from 0.76466 to 0.76397, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 22s - loss: 0.6872 - accuracy: 0.7200 - val_loss: 0.7640 - val_accuracy: 0.6978
# Epoch 47/150
#
# Epoch 00047: val_loss improved from 0.76397 to 0.76203, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 22s - loss: 0.6846 - accuracy: 0.7206 - val_loss: 0.7620 - val_accuracy: 0.6978
# Epoch 48/150
#
# Epoch 00048: val_loss improved from 0.76203 to 0.76198, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 22s - loss: 0.6820 - accuracy: 0.7200 - val_loss: 0.7620 - val_accuracy: 0.6983
# Epoch 49/150
#
# Epoch 00049: val_loss improved from 0.76198 to 0.75682, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 22s - loss: 0.6794 - accuracy: 0.7215 - val_loss: 0.7568 - val_accuracy: 0.6999
# Epoch 50/150
#
# Epoch 00050: val_loss did not improve from 0.75682
# 1217/1217 - 23s - loss: 0.6795 - accuracy: 0.7195 - val_loss: 0.7578 - val_accuracy: 0.7017
# Epoch 51/150
#
# Epoch 00051: val_loss improved from 0.75682 to 0.75270, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 22s - loss: 0.6756 - accuracy: 0.7220 - val_loss: 0.7527 - val_accuracy: 0.7009
# Epoch 52/150
#
# Epoch 00052: val_loss did not improve from 0.75270
# 1217/1217 - 23s - loss: 0.6726 - accuracy: 0.7206 - val_loss: 0.7556 - val_accuracy: 0.7013
# Epoch 53/150
#
# Epoch 00053: val_loss did not improve from 0.75270
# 1217/1217 - 22s - loss: 0.6715 - accuracy: 0.7215 - val_loss: 0.7538 - val_accuracy: 0.7017
# Epoch 54/150
#
# Epoch 00054: val_loss improved from 0.75270 to 0.75065, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 22s - loss: 0.6696 - accuracy: 0.7218 - val_loss: 0.7507 - val_accuracy: 0.7020
# Epoch 55/150
#
# Epoch 00055: val_loss improved from 0.75065 to 0.74642, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 22s - loss: 0.6667 - accuracy: 0.7241 - val_loss: 0.7464 - val_accuracy: 0.7040
# Epoch 56/150
#
# Epoch 00056: val_loss improved from 0.74642 to 0.74634, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 22s - loss: 0.6680 - accuracy: 0.7235 - val_loss: 0.7463 - val_accuracy: 0.7044
# Epoch 57/150
#
# Epoch 00057: val_loss improved from 0.74634 to 0.74486, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 22s - loss: 0.6671 - accuracy: 0.7248 - val_loss: 0.7449 - val_accuracy: 0.7048
# Epoch 58/150
#
# Epoch 00058: val_loss improved from 0.74486 to 0.74198, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 22s - loss: 0.6618 - accuracy: 0.7236 - val_loss: 0.7420 - val_accuracy: 0.7050
# Epoch 59/150
#
# Epoch 00059: val_loss improved from 0.74198 to 0.74161, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 23s - loss: 0.6600 - accuracy: 0.7233 - val_loss: 0.7416 - val_accuracy: 0.7046
# Epoch 60/150
#
# Epoch 00060: val_loss did not improve from 0.74161
# 1217/1217 - 24s - loss: 0.6573 - accuracy: 0.7230 - val_loss: 0.7453 - val_accuracy: 0.7038
# Epoch 61/150
#
# Epoch 00061: val_loss improved from 0.74161 to 0.74101, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 25s - loss: 0.6546 - accuracy: 0.7240 - val_loss: 0.7410 - val_accuracy: 0.7050
# Epoch 62/150
#
# Epoch 00062: val_loss improved from 0.74101 to 0.73913, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 18s - loss: 0.6561 - accuracy: 0.7252 - val_loss: 0.7391 - val_accuracy: 0.7052
# Epoch 63/150
#
# Epoch 00063: val_loss did not improve from 0.73913
# 1217/1217 - 16s - loss: 0.6515 - accuracy: 0.7261 - val_loss: 0.7412 - val_accuracy: 0.7050
# Epoch 64/150
#
# Epoch 00064: val_loss improved from 0.73913 to 0.73844, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 16s - loss: 0.6498 - accuracy: 0.7255 - val_loss: 0.7384 - val_accuracy: 0.7052
# Epoch 65/150
#
# Epoch 00065: val_loss improved from 0.73844 to 0.73627, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 16s - loss: 0.6516 - accuracy: 0.7251 - val_loss: 0.7363 - val_accuracy: 0.7048
# Epoch 66/150
#
# Epoch 00066: val_loss improved from 0.73627 to 0.73386, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 16s - loss: 0.6493 - accuracy: 0.7277 - val_loss: 0.7339 - val_accuracy: 0.7042
# Epoch 67/150
#
# Epoch 00067: val_loss improved from 0.73386 to 0.73353, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 17s - loss: 0.6486 - accuracy: 0.7270 - val_loss: 0.7335 - val_accuracy: 0.7059
# Epoch 68/150
#
# Epoch 00068: val_loss improved from 0.73353 to 0.73269, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 16s - loss: 0.6448 - accuracy: 0.7275 - val_loss: 0.7327 - val_accuracy: 0.7075
# Epoch 69/150
#
# Epoch 00069: val_loss improved from 0.73269 to 0.73080, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 17s - loss: 0.6441 - accuracy: 0.7256 - val_loss: 0.7308 - val_accuracy: 0.7069
# Epoch 70/150
#
# Epoch 00070: val_loss did not improve from 0.73080
# 1217/1217 - 17s - loss: 0.6432 - accuracy: 0.7258 - val_loss: 0.7310 - val_accuracy: 0.7071
# Epoch 71/150
#
# Epoch 00071: val_loss improved from 0.73080 to 0.72656, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 16s - loss: 0.6402 - accuracy: 0.7296 - val_loss: 0.7266 - val_accuracy: 0.7085
# Epoch 72/150
#
# Epoch 00072: val_loss did not improve from 0.72656
# 1217/1217 - 15s - loss: 0.6408 - accuracy: 0.7287 - val_loss: 0.7277 - val_accuracy: 0.7087
# Epoch 73/150
#
# Epoch 00073: val_loss did not improve from 0.72656
# 1217/1217 - 16s - loss: 0.6373 - accuracy: 0.7296 - val_loss: 0.7286 - val_accuracy: 0.7067
# Epoch 74/150
#
# Epoch 00074: val_loss improved from 0.72656 to 0.72393, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 16s - loss: 0.6353 - accuracy: 0.7285 - val_loss: 0.7239 - val_accuracy: 0.7087
# Epoch 75/150
#
# Epoch 00075: val_loss did not improve from 0.72393
# 1217/1217 - 18s - loss: 0.6320 - accuracy: 0.7291 - val_loss: 0.7288 - val_accuracy: 0.7073
# Epoch 76/150
#
# Epoch 00076: val_loss improved from 0.72393 to 0.72127, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 17s - loss: 0.6354 - accuracy: 0.7295 - val_loss: 0.7213 - val_accuracy: 0.7114
# Epoch 77/150
#
# Epoch 00077: val_loss did not improve from 0.72127
# 1217/1217 - 16s - loss: 0.6327 - accuracy: 0.7279 - val_loss: 0.7254 - val_accuracy: 0.7085
# Epoch 78/150
#
# Epoch 00078: val_loss improved from 0.72127 to 0.72107, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 16s - loss: 0.6326 - accuracy: 0.7297 - val_loss: 0.7211 - val_accuracy: 0.7108
# Epoch 79/150
#
# Epoch 00079: val_loss did not improve from 0.72107
# 1217/1217 - 16s - loss: 0.6318 - accuracy: 0.7303 - val_loss: 0.7236 - val_accuracy: 0.7094
# Epoch 80/150
#
# Epoch 00080: val_loss did not improve from 0.72107
# 1217/1217 - 16s - loss: 0.6272 - accuracy: 0.7295 - val_loss: 0.7218 - val_accuracy: 0.7122
# Epoch 81/150
#
# Epoch 00081: val_loss improved from 0.72107 to 0.72089, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 17s - loss: 0.6268 - accuracy: 0.7318 - val_loss: 0.7209 - val_accuracy: 0.7102
# Epoch 82/150
#
# Epoch 00082: val_loss improved from 0.72089 to 0.71873, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 17s - loss: 0.6277 - accuracy: 0.7293 - val_loss: 0.7187 - val_accuracy: 0.7120
# Epoch 83/150
#
# Epoch 00083: val_loss did not improve from 0.71873
# 1217/1217 - 16s - loss: 0.6249 - accuracy: 0.7312 - val_loss: 0.7197 - val_accuracy: 0.7120
# Epoch 84/150
#
# Epoch 00084: val_loss improved from 0.71873 to 0.71522, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 17s - loss: 0.6236 - accuracy: 0.7318 - val_loss: 0.7152 - val_accuracy: 0.7126
# Epoch 85/150
#
# Epoch 00085: val_loss did not improve from 0.71522
# 1217/1217 - 17s - loss: 0.6226 - accuracy: 0.7311 - val_loss: 0.7169 - val_accuracy: 0.7135
# Epoch 86/150
#
# Epoch 00086: val_loss did not improve from 0.71522
# 1217/1217 - 16s - loss: 0.6194 - accuracy: 0.7352 - val_loss: 0.7178 - val_accuracy: 0.7104
# Epoch 87/150
#
# Epoch 00087: val_loss did not improve from 0.71522
# 1217/1217 - 16s - loss: 0.6201 - accuracy: 0.7345 - val_loss: 0.7179 - val_accuracy: 0.7128
# Epoch 88/150
#
# Epoch 00088: val_loss improved from 0.71522 to 0.71260, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 16s - loss: 0.6174 - accuracy: 0.7342 - val_loss: 0.7126 - val_accuracy: 0.7133
# Epoch 89/150
#
# Epoch 00089: val_loss did not improve from 0.71260
# 1217/1217 - 16s - loss: 0.6189 - accuracy: 0.7330 - val_loss: 0.7164 - val_accuracy: 0.7120
# Epoch 90/150
#
# Epoch 00090: val_loss improved from 0.71260 to 0.71203, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 18s - loss: 0.6162 - accuracy: 0.7332 - val_loss: 0.7120 - val_accuracy: 0.7149
# Epoch 91/150
#
# Epoch 00091: val_loss did not improve from 0.71203
# 1217/1217 - 16s - loss: 0.6165 - accuracy: 0.7333 - val_loss: 0.7151 - val_accuracy: 0.7106
# Epoch 92/150
#
# Epoch 00092: val_loss improved from 0.71203 to 0.71195, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 16s - loss: 0.6161 - accuracy: 0.7346 - val_loss: 0.7120 - val_accuracy: 0.7151
# Epoch 93/150
#
# Epoch 00093: val_loss improved from 0.71195 to 0.71163, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 16s - loss: 0.6147 - accuracy: 0.7317 - val_loss: 0.7116 - val_accuracy: 0.7155
# Epoch 94/150
#
# Epoch 00094: val_loss improved from 0.71163 to 0.70639, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 16s - loss: 0.6131 - accuracy: 0.7327 - val_loss: 0.7064 - val_accuracy: 0.7159
# Epoch 95/150
#
# Epoch 00095: val_loss did not improve from 0.70639
# 1217/1217 - 16s - loss: 0.6132 - accuracy: 0.7368 - val_loss: 0.7103 - val_accuracy: 0.7145
# Epoch 96/150
#
# Epoch 00096: val_loss improved from 0.70639 to 0.70588, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 16s - loss: 0.6100 - accuracy: 0.7370 - val_loss: 0.7059 - val_accuracy: 0.7178
# Epoch 97/150
#
# Epoch 00097: val_loss improved from 0.70588 to 0.70373, saving model to ./models_saved/model_d_conv1d_mfcc40_pol.h5
# 1217/1217 - 17s - loss: 0.6103 - accuracy: 0.7367 - val_loss: 0.7037 - val_accuracy: 0.7178
# Epoch 98/150
#
# Epoch 00098: val_loss did not improve from 0.70373
# 1217/1217 - 17s - loss: 0.6081 - accuracy: 0.7366 - val_loss: 0.7082 - val_accuracy: 0.7165
# Epoch 99/150
#
# Epoch 00099: val_loss did not improve from 0.70373
# 1217/1217 - 16s - loss: 0.6097 - accuracy: 0.7346 - val_loss: 0.7065 - val_accuracy: 0.7155
# Epoch 100/150
#
# Epoch 00100: val_loss did not improve from 0.70373
# 1217/1217 - 16s - loss: 0.6078 - accuracy: 0.7378 - val_loss: 0.7060 - val_accuracy: 0.7163
# Epoch 101/150
#
# Epoch 00101: val_loss did not improve from 0.70373
# 1217/1217 - 16s - loss: 0.6072 - accuracy: 0.7398 - val_loss: 0.7050 - val_accuracy: 0.7174

# %%
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
score,acc = model.evaluate(X_test, y_test, verbose = 2, batch_size = batch_size)
print("score: %.2f" % (score))
print("acc: %.2f" % (acc))
# Out:
# 305/305 - 1s - loss: 0.7059 - accuracy: 0.7178
# score: 0.71
# acc: 0.72

# %%
# load labels
with open('./Data_Array_Storage/labels_mfcc40_axis0_pol.pkl', 'rb') as f:
    lb = pickle.load(f)

# %%
# error analysis

preds = model.predict(X_test, 
                         batch_size=batch_size, 
                         verbose=1)

preds=preds.argmax(axis=1)
preds
# Out:
# 305/305 [==============================] - 1s 2ms/step
# array([0, 0, 0, ..., 0, 0, 0])

# %%
# predictions 
preds = preds.astype(int).flatten()
preds = (lb.inverse_transform((preds)))
preds = pd.DataFrame({'predictedvalues': preds})

# Actual labels
actual = y_test.argmax(axis=1)
actual = actual.astype(int).flatten()
actual = (lb.inverse_transform((actual)))
actual = pd.DataFrame({'actualvalues': actual})

# Lets combined both of them into a single dataframe
finaldf = actual.join(preds)
finaldf[150:180]
# Out:
#     actualvalues predictedvalues
# 150     negative        negative
# 151     negative        negative
# 152     negative        negative
# 153     negative        negative
# 154      neutral        negative
# 155     negative        negative
# 156     negative        negative
# 157     negative        negative
# 158     negative        negative
# 159     negative        negative
# 160     negative        negative
# 161     negative        negative
# 162     negative        negative
# 163     negative        negative
# 164     negative        negative
# 165     negative        negative
# 166     negative        negative
# 167      neutral         neutral
# 168      neutral         neutral
# 169     negative        negative
# 170      neutral         neutral
# 171      neutral        negative
# 172      neutral         neutral
# 173     negative        negative
# 174     negative        negative
# 175     negative        negative
# 176      neutral        negative
# 177     positive        negative
# 178     negative        negative
# 179      neutral        negative

# %%
# the confusion matrix heat map plot
def print_confusion_matrix(confusion_matrix, class_names, figsize = (10,7), fontsize=14):
    """Prints a confusion matrix, as returned by sklearn.metrics.confusion_matrix, as a heatmap.
    
    Arguments
    ---------
    confusion_matrix: numpy.ndarray
        The numpy.ndarray object returned from a call to sklearn.metrics.confusion_matrix. 
        Similarly constructed ndarrays can also be used.
    class_names: list
        An ordered list of class names, in the order they index the given confusion matrix.
    figsize: tuple
        A 2-long tuple, the first value determining the horizontal size of the ouputted figure,
        the second determining the vertical size. Defaults to (10,7).
    fontsize: int
        Font size for axes labels. Defaults to 14.
        
    Returns
    -------
    matplotlib.figure.Figure
        The resulting confusion matrix figure
    """
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names, columns=class_names, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
        
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
# Get the predictions file 
# finaldf = pd.read_csv("Predictions.csv")
classes = finaldf.actualvalues.unique()
classes.sort()    

# Confusion matrix 
c = confusion_matrix(finaldf.actualvalues, finaldf.predictedvalues)
print(accuracy_score(finaldf.actualvalues, finaldf.predictedvalues))
print_confusion_matrix(c, class_names = classes)
# Out:
# 0.7177800616649538

# %%
# Classification report 
classes = finaldf.actualvalues.unique()
classes.sort()    
print(classification_report(finaldf.actualvalues, finaldf.predictedvalues, target_names=classes))
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.70      0.99      0.82      3070
#      neutral       0.89      0.22      0.35       748
#     positive       0.93      0.28      0.43      1047
#
#     accuracy                           0.72      4865
#    macro avg       0.84      0.50      0.53      4865
# weighted avg       0.77      0.72      0.66      4865
