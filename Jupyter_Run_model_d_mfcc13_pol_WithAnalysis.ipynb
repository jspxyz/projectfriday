# %%
'''
Creating to run Model D Conv1d_mfcc40
different layer system
full mfcc 13 features
Created on 2020.12.11
Label: Polarity

'''
# libraries
import numpy as np
import pandas as pd
import pickle
import seaborn as sns
import tensorflow as tf

from tensorflow.keras.layers import Dense, Dropout, Flatten, Input
from tensorflow.keras.layers import Activation, BatchNormalization
from tensorflow.keras.layers import Conv1D, Conv2D, LSTM
from tensorflow.keras.layers import AveragePooling1D, GlobalAveragePooling2D, MaxPooling1D
from tensorflow.keras.models import Model, model_from_json, Sequential

# added this to plot
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
# load datasets

# assigning the pickle files
with open('./Data_Array_Storage/X_train_mfcc13_axis0_pol.pkl', 'rb') as f:
    X_train = pickle.load(f)

with open('./Data_Array_Storage/X_test_mfcc13_axis0_pol.pkl', 'rb') as f:
    X_test = pickle.load(f)

with open('./Data_Array_Storage/y_train_mfcc13_axis0_pol.pkl', 'rb') as f:
    y_train = pickle.load(f)

with open('./Data_Array_Storage/y_test_mfcc13_axis0_pol.pkl', 'rb') as f:
    y_test = pickle.load(f)
    
print('dataset loaded')
# Out:
# dataset loaded

# %%
# input shape
input_shape = (X_train.shape[1], X_train.shape[2])
print(input_shape)
# Out:
# (216, 13)

# %%
def model_d_conv1d(input_shape):
    model = Sequential()
    model.add(Conv1D(32, 3, padding='same',input_shape=input_shape))  # X_train.shape[1] = No. of Columns (216)
    model.add(Activation('relu'))
    model.add(Conv1D(32, 3, padding='same'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.25))
    model.add(MaxPooling1D(pool_size=(3)))
    model.add(Conv1D(64, 3, padding='same'))
    model.add(Activation('relu'))
    model.add(Conv1D(64, 3, padding='same'))
    model.add(Dropout(0.25))
    model.add(MaxPooling1D(pool_size=(3))) # added drop out and maxpooling layer on 20201209 at 1330
    model.add(Activation('relu'))
    model.add(Conv1D(64, 3, padding='same'))
    model.add(Activation('relu'))
    model.add(Conv1D(64, 3, padding='same'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.25))
    model.add(MaxPooling1D(pool_size=(3)))
    model.add(Conv1D(128, 3, padding='same'))
    model.add(Activation('relu'))
    model.add(Conv1D(128, 3, padding='same'))
    model.add(Activation('relu'))
    model.add(Conv1D(256, 3, padding='same'))
    model.add(Activation('relu'))
#     model.add(LSTM(64))
    model.add(Flatten())
    model.add(Dense(3)) # Target class number
    model.add(Activation('softmax'))
    
    # model optimizer
#     model = model_d_conv1d(input_shape)
    optimizer = tf.keras.optimizers.RMSprop(lr=0.000001, decay=1e-6)
    
    # compile model
    model.compile(loss='categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])

    return model

# %%
def model_d_conv1d_flip(input_shape):
    model = Sequential()
    model.add(Conv1D(256, 3, padding='same',input_shape=input_shape))  # X_train.shape[1] = No. of Columns (216)
    model.add(Activation('relu'))
    model.add(Conv1D(256, 3, padding='same'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.25))
    model.add(MaxPooling1D(pool_size=(3)))
    model.add(Conv1D(128, 3, padding='same'))
    model.add(Activation('relu'))
    model.add(Conv1D(128, 3, padding='same'))
    model.add(Dropout(0.25))
    model.add(MaxPooling1D(pool_size=(3))) # added drop out and maxpooling layer on 20201209 at 1330
    model.add(Activation('relu'))
    model.add(Conv1D(128, 3, padding='same'))
    model.add(Activation('relu'))
    model.add(Conv1D(128, 3, padding='same'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.25))
    model.add(MaxPooling1D(pool_size=(3)))
    model.add(Conv1D(64, 3, padding='same'))
    model.add(Activation('relu'))
    model.add(Conv1D(64, 3, padding='same'))
    model.add(Activation('relu'))
    model.add(Conv1D(32, 3, padding='same'))
    model.add(Activation('relu'))
    model.add(Flatten())
    model.add(Dense(3)) # Target class number
    model.add(Activation('softmax'))
    
    # model optimizer
#     model = model_d_conv1d(input_shape)
    optimizer = tf.keras.optimizers.RMSprop(lr=0.000001, decay=1e-6)
    
    # compile model
    model.compile(loss='categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])

    return model

# %%
# load model and input shape
# from models import model_d_conv1d

# model = model_d_conv1d_flip(input_shape)
model = model_d_conv1d(input_shape)
# optimizer = tf.keras.optimizers.RMSprop(lr=0.000001, decay=1e-6)

print('input shape, model, optimizer loaded')

model.summary()
# Out:
# input shape, model, optimizer loaded
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_27 (Conv1D)           (None, 216, 32)           1280
# _________________________________________________________________
# activation_30 (Activation)   (None, 216, 32)           0
# _________________________________________________________________
# conv1d_28 (Conv1D)           (None, 216, 32)           3104
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 216, 32)           128
# _________________________________________________________________
# activation_31 (Activation)   (None, 216, 32)           0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 216, 32)           0
# _________________________________________________________________
# max_pooling1d_9 (MaxPooling1 (None, 72, 32)            0
# _________________________________________________________________
# conv1d_29 (Conv1D)           (None, 72, 64)            6208
# _________________________________________________________________
# activation_32 (Activation)   (None, 72, 64)            0
# _________________________________________________________________
# conv1d_30 (Conv1D)           (None, 72, 64)            12352
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 72, 64)            0
# _________________________________________________________________
# max_pooling1d_10 (MaxPooling (None, 24, 64)            0
# _________________________________________________________________
# activation_33 (Activation)   (None, 24, 64)            0
# _________________________________________________________________
# conv1d_31 (Conv1D)           (None, 24, 64)            12352
# _________________________________________________________________
# activation_34 (Activation)   (None, 24, 64)            0
# _________________________________________________________________
# conv1d_32 (Conv1D)           (None, 24, 64)            12352
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 24, 64)            256
# _________________________________________________________________
# activation_35 (Activation)   (None, 24, 64)            0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 24, 64)            0
# _________________________________________________________________
# max_pooling1d_11 (MaxPooling (None, 8, 64)             0
# _________________________________________________________________
# conv1d_33 (Conv1D)           (None, 8, 128)            24704
# _________________________________________________________________
# activation_36 (Activation)   (None, 8, 128)            0
# _________________________________________________________________
# conv1d_34 (Conv1D)           (None, 8, 128)            49280
# _________________________________________________________________
# activation_37 (Activation)   (None, 8, 128)            0
# _________________________________________________________________
# conv1d_35 (Conv1D)           (None, 8, 256)            98560
# _________________________________________________________________
# activation_38 (Activation)   (None, 8, 256)            0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 6147
# _________________________________________________________________
# activation_39 (Activation)   (None, 3)                 0
# =================================================================
# Total params: 226,723
# Trainable params: 226,531
# Non-trainable params: 192
# _________________________________________________________________

# %%
# callback list: ModelCheckpoint, reduceLROnPlat, EarlyStopping
# checkpoint_path = "./models_saved/model_d_conv1d_v3.h5"

checkpoint_path = "./models_saved/model_d_conv1d_mfcc13_pol.h5"

# Create a callback that saves the model's weights
callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=False,
                                                 save_best_only=True,
                                                 verbose=1), # 1 tells your which epoch is saving
#                                                  monitor='val_categorical_accuracy',  # added for emo1d
#                                                  mode='max'), # added for emo1d
               tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', # changed from 'val_accuracy', 'val_loss'
                                                patience=5, 
                                                restore_best_weights=True),
#                                                 verbose = 1, # added verbose for emo1d
#                                                 mode = 'min'), # added for emo1d
               tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', 
                                                    patience=2, 
                                                    factor=0.5, 
                                                    min_lr=0.000001, 
                                                    verbose=1)]

print('callbacks and checkpoints set')
# Out:
# callbacks and checkpoints set

# %%
batch_size = 16

model_history=model.fit(X_train, 
                        y_train,
                        batch_size=batch_size,
                        epochs=150,
                        validation_data=(X_test, y_test),
                        verbose=2,
                        callbacks=callbacks)
# Out:
# Epoch 1/150
#
# Epoch 00001: val_loss improved from inf to 0.94255, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 26s - loss: 0.9718 - accuracy: 0.5708 - val_loss: 0.9426 - val_accuracy: 0.6310
# Epoch 2/150
#
# Epoch 00002: val_loss improved from 0.94255 to 0.92723, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 24s - loss: 0.8977 - accuracy: 0.6328 - val_loss: 0.9272 - val_accuracy: 0.6310
# Epoch 3/150
#
# Epoch 00003: val_loss improved from 0.92723 to 0.92135, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 26s - loss: 0.8872 - accuracy: 0.6329 - val_loss: 0.9213 - val_accuracy: 0.6310
# Epoch 4/150
#
# Epoch 00004: val_loss improved from 0.92135 to 0.91375, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 28s - loss: 0.8772 - accuracy: 0.6331 - val_loss: 0.9138 - val_accuracy: 0.6312
# Epoch 5/150
#
# Epoch 00005: val_loss improved from 0.91375 to 0.91114, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 31s - loss: 0.8717 - accuracy: 0.6344 - val_loss: 0.9111 - val_accuracy: 0.6317
# Epoch 6/150
#
# Epoch 00006: val_loss improved from 0.91114 to 0.90566, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 27s - loss: 0.8650 - accuracy: 0.6369 - val_loss: 0.9057 - val_accuracy: 0.6321
# Epoch 7/150
#
# Epoch 00007: val_loss improved from 0.90566 to 0.90210, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 27s - loss: 0.8577 - accuracy: 0.6389 - val_loss: 0.9021 - val_accuracy: 0.6327
# Epoch 8/150
#
# Epoch 00008: val_loss improved from 0.90210 to 0.90008, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 28s - loss: 0.8538 - accuracy: 0.6411 - val_loss: 0.9001 - val_accuracy: 0.6343
# Epoch 9/150
#
# Epoch 00009: val_loss improved from 0.90008 to 0.89603, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 27s - loss: 0.8481 - accuracy: 0.6452 - val_loss: 0.8960 - val_accuracy: 0.6351
# Epoch 10/150
#
# Epoch 00010: val_loss improved from 0.89603 to 0.89282, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 30s - loss: 0.8452 - accuracy: 0.6477 - val_loss: 0.8928 - val_accuracy: 0.6362
# Epoch 11/150
#
# Epoch 00011: val_loss improved from 0.89282 to 0.89168, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 31s - loss: 0.8403 - accuracy: 0.6510 - val_loss: 0.8917 - val_accuracy: 0.6372
# Epoch 12/150
#
# Epoch 00012: val_loss improved from 0.89168 to 0.88716, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 29s - loss: 0.8357 - accuracy: 0.6557 - val_loss: 0.8872 - val_accuracy: 0.6378
# Epoch 13/150
#
# Epoch 00013: val_loss improved from 0.88716 to 0.88502, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 28s - loss: 0.8328 - accuracy: 0.6549 - val_loss: 0.8850 - val_accuracy: 0.6403
# Epoch 14/150
#
# Epoch 00014: val_loss improved from 0.88502 to 0.88017, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 28s - loss: 0.8264 - accuracy: 0.6602 - val_loss: 0.8802 - val_accuracy: 0.6399
# Epoch 15/150
#
# Epoch 00015: val_loss improved from 0.88017 to 0.87838, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 26s - loss: 0.8214 - accuracy: 0.6607 - val_loss: 0.8784 - val_accuracy: 0.6421
# Epoch 16/150
#
# Epoch 00016: val_loss improved from 0.87838 to 0.87573, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 28s - loss: 0.8165 - accuracy: 0.6622 - val_loss: 0.8757 - val_accuracy: 0.6428
# Epoch 17/150
#
# Epoch 00017: val_loss improved from 0.87573 to 0.87093, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 28s - loss: 0.8143 - accuracy: 0.6647 - val_loss: 0.8709 - val_accuracy: 0.6444
# Epoch 18/150
#
# Epoch 00018: val_loss improved from 0.87093 to 0.86924, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 20s - loss: 0.8075 - accuracy: 0.6671 - val_loss: 0.8692 - val_accuracy: 0.6460
# Epoch 19/150
#
# Epoch 00019: val_loss improved from 0.86924 to 0.86712, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 22s - loss: 0.8038 - accuracy: 0.6693 - val_loss: 0.8671 - val_accuracy: 0.6483
# Epoch 20/150
#
# Epoch 00020: val_loss improved from 0.86712 to 0.86456, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 22s - loss: 0.7997 - accuracy: 0.6716 - val_loss: 0.8646 - val_accuracy: 0.6524
# Epoch 21/150
#
# Epoch 00021: val_loss improved from 0.86456 to 0.85949, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 21s - loss: 0.7948 - accuracy: 0.6713 - val_loss: 0.8595 - val_accuracy: 0.6543
# Epoch 22/150
#
# Epoch 00022: val_loss improved from 0.85949 to 0.85698, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 23s - loss: 0.7912 - accuracy: 0.6736 - val_loss: 0.8570 - val_accuracy: 0.6534
# Epoch 23/150
#
# Epoch 00023: val_loss improved from 0.85698 to 0.85316, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 24s - loss: 0.7874 - accuracy: 0.6749 - val_loss: 0.8532 - val_accuracy: 0.6592
# Epoch 24/150
#
# Epoch 00024: val_loss improved from 0.85316 to 0.85253, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 24s - loss: 0.7832 - accuracy: 0.6763 - val_loss: 0.8525 - val_accuracy: 0.6604
# Epoch 25/150
#
# Epoch 00025: val_loss improved from 0.85253 to 0.84941, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 22s - loss: 0.7780 - accuracy: 0.6759 - val_loss: 0.8494 - val_accuracy: 0.6627
# Epoch 26/150
#
# Epoch 00026: val_loss improved from 0.84941 to 0.84592, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 21s - loss: 0.7761 - accuracy: 0.6779 - val_loss: 0.8459 - val_accuracy: 0.6641
# Epoch 27/150
#
# Epoch 00027: val_loss improved from 0.84592 to 0.84077, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 21s - loss: 0.7706 - accuracy: 0.6783 - val_loss: 0.8408 - val_accuracy: 0.6643
# Epoch 28/150
#
# Epoch 00028: val_loss improved from 0.84077 to 0.83894, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 21s - loss: 0.7713 - accuracy: 0.6794 - val_loss: 0.8389 - val_accuracy: 0.6662
# Epoch 29/150
#
# Epoch 00029: val_loss improved from 0.83894 to 0.83604, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 21s - loss: 0.7661 - accuracy: 0.6840 - val_loss: 0.8360 - val_accuracy: 0.6664
# Epoch 30/150
#
# Epoch 00030: val_loss improved from 0.83604 to 0.83429, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 21s - loss: 0.7642 - accuracy: 0.6835 - val_loss: 0.8343 - val_accuracy: 0.6687
# Epoch 31/150
#
# Epoch 00031: val_loss improved from 0.83429 to 0.83365, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 23s - loss: 0.7600 - accuracy: 0.6833 - val_loss: 0.8337 - val_accuracy: 0.6693
# Epoch 32/150
#
# Epoch 00032: val_loss improved from 0.83365 to 0.82976, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 21s - loss: 0.7557 - accuracy: 0.6864 - val_loss: 0.8298 - val_accuracy: 0.6719
# Epoch 33/150
#
# Epoch 00033: val_loss improved from 0.82976 to 0.82858, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 22s - loss: 0.7544 - accuracy: 0.6868 - val_loss: 0.8286 - val_accuracy: 0.6721
# Epoch 34/150
#
# Epoch 00034: val_loss improved from 0.82858 to 0.82607, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 21s - loss: 0.7512 - accuracy: 0.6868 - val_loss: 0.8261 - val_accuracy: 0.6740
# Epoch 35/150
#
# Epoch 00035: val_loss improved from 0.82607 to 0.82371, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 21s - loss: 0.7485 - accuracy: 0.6886 - val_loss: 0.8237 - val_accuracy: 0.6754
# Epoch 36/150
#
# Epoch 00036: val_loss improved from 0.82371 to 0.82144, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 21s - loss: 0.7453 - accuracy: 0.6909 - val_loss: 0.8214 - val_accuracy: 0.6785
# Epoch 37/150
#
# Epoch 00037: val_loss improved from 0.82144 to 0.81818, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 21s - loss: 0.7433 - accuracy: 0.6890 - val_loss: 0.8182 - val_accuracy: 0.6779
# Epoch 38/150
#
# Epoch 00038: val_loss improved from 0.81818 to 0.81404, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 21s - loss: 0.7420 - accuracy: 0.6907 - val_loss: 0.8140 - val_accuracy: 0.6806
# Epoch 39/150
#
# Epoch 00039: val_loss did not improve from 0.81404
# 1217/1217 - 21s - loss: 0.7394 - accuracy: 0.6941 - val_loss: 0.8150 - val_accuracy: 0.6804
# Epoch 40/150
#
# Epoch 00040: val_loss improved from 0.81404 to 0.81165, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 22s - loss: 0.7360 - accuracy: 0.6945 - val_loss: 0.8116 - val_accuracy: 0.6816
# Epoch 41/150
#
# Epoch 00041: val_loss did not improve from 0.81165
# 1217/1217 - 21s - loss: 0.7360 - accuracy: 0.6921 - val_loss: 0.8122 - val_accuracy: 0.6824
# Epoch 42/150
#
# Epoch 00042: val_loss improved from 0.81165 to 0.81002, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 22s - loss: 0.7328 - accuracy: 0.6944 - val_loss: 0.8100 - val_accuracy: 0.6841
# Epoch 43/150
#
# Epoch 00043: val_loss improved from 0.81002 to 0.80668, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 22s - loss: 0.7308 - accuracy: 0.6917 - val_loss: 0.8067 - val_accuracy: 0.6841
# Epoch 44/150
#
# Epoch 00044: val_loss improved from 0.80668 to 0.80465, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 21s - loss: 0.7267 - accuracy: 0.6972 - val_loss: 0.8047 - val_accuracy: 0.6851
# Epoch 45/150
#
# Epoch 00045: val_loss improved from 0.80465 to 0.80365, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 21s - loss: 0.7274 - accuracy: 0.6937 - val_loss: 0.8037 - val_accuracy: 0.6872
# Epoch 46/150
#
# Epoch 00046: val_loss improved from 0.80365 to 0.80223, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 21s - loss: 0.7224 - accuracy: 0.6954 - val_loss: 0.8022 - val_accuracy: 0.6861
# Epoch 47/150
#
# Epoch 00047: val_loss improved from 0.80223 to 0.79929, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 21s - loss: 0.7176 - accuracy: 0.6972 - val_loss: 0.7993 - val_accuracy: 0.6878
# Epoch 48/150
#
# Epoch 00048: val_loss improved from 0.79929 to 0.79811, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 20s - loss: 0.7182 - accuracy: 0.6999 - val_loss: 0.7981 - val_accuracy: 0.6880
# Epoch 49/150
#
# Epoch 00049: val_loss improved from 0.79811 to 0.79680, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 20s - loss: 0.7172 - accuracy: 0.6984 - val_loss: 0.7968 - val_accuracy: 0.6884
# Epoch 50/150
#
# Epoch 00050: val_loss improved from 0.79680 to 0.79624, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 20s - loss: 0.7153 - accuracy: 0.6976 - val_loss: 0.7962 - val_accuracy: 0.6894
# Epoch 51/150
#
# Epoch 00051: val_loss improved from 0.79624 to 0.79237, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 21s - loss: 0.7125 - accuracy: 0.6998 - val_loss: 0.7924 - val_accuracy: 0.6896
# Epoch 52/150
#
# Epoch 00052: val_loss did not improve from 0.79237
# 1217/1217 - 21s - loss: 0.7115 - accuracy: 0.7018 - val_loss: 0.7929 - val_accuracy: 0.6894
# Epoch 53/150
#
# Epoch 00053: val_loss did not improve from 0.79237
# 1217/1217 - 20s - loss: 0.7109 - accuracy: 0.6990 - val_loss: 0.7924 - val_accuracy: 0.6896
# Epoch 54/150
#
# Epoch 00054: val_loss improved from 0.79237 to 0.79068, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 21s - loss: 0.7097 - accuracy: 0.7000 - val_loss: 0.7907 - val_accuracy: 0.6904
# Epoch 55/150
#
# Epoch 00055: val_loss improved from 0.79068 to 0.78985, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 21s - loss: 0.7082 - accuracy: 0.6997 - val_loss: 0.7898 - val_accuracy: 0.6906
# Epoch 56/150
#
# Epoch 00056: val_loss improved from 0.78985 to 0.78789, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 22s - loss: 0.7057 - accuracy: 0.7017 - val_loss: 0.7879 - val_accuracy: 0.6904
# Epoch 57/150
#
# Epoch 00057: val_loss improved from 0.78789 to 0.78655, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 21s - loss: 0.7029 - accuracy: 0.7054 - val_loss: 0.7866 - val_accuracy: 0.6909
# Epoch 58/150
#
# Epoch 00058: val_loss improved from 0.78655 to 0.78275, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 21s - loss: 0.7027 - accuracy: 0.7014 - val_loss: 0.7827 - val_accuracy: 0.6909
# Epoch 59/150
#
# Epoch 00059: val_loss did not improve from 0.78275
# 1217/1217 - 21s - loss: 0.6982 - accuracy: 0.7047 - val_loss: 0.7829 - val_accuracy: 0.6911
# Epoch 60/150
#
# Epoch 00060: val_loss did not improve from 0.78275
# 1217/1217 - 20s - loss: 0.6967 - accuracy: 0.7039 - val_loss: 0.7832 - val_accuracy: 0.6919
# Epoch 61/150
#
# Epoch 00061: val_loss improved from 0.78275 to 0.78244, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 21s - loss: 0.6978 - accuracy: 0.7025 - val_loss: 0.7824 - val_accuracy: 0.6929
# Epoch 62/150
#
# Epoch 00062: val_loss improved from 0.78244 to 0.78045, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 20s - loss: 0.6965 - accuracy: 0.7028 - val_loss: 0.7804 - val_accuracy: 0.6927
# Epoch 63/150
#
# Epoch 00063: val_loss improved from 0.78045 to 0.77961, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 20s - loss: 0.6939 - accuracy: 0.7035 - val_loss: 0.7796 - val_accuracy: 0.6931
# Epoch 64/150
#
# Epoch 00064: val_loss improved from 0.77961 to 0.77919, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 21s - loss: 0.6913 - accuracy: 0.7039 - val_loss: 0.7792 - val_accuracy: 0.6923
# Epoch 65/150
#
# Epoch 00065: val_loss improved from 0.77919 to 0.77730, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 21s - loss: 0.6886 - accuracy: 0.7077 - val_loss: 0.7773 - val_accuracy: 0.6931
# Epoch 66/150
#
# Epoch 00066: val_loss improved from 0.77730 to 0.77690, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 21s - loss: 0.6888 - accuracy: 0.7059 - val_loss: 0.7769 - val_accuracy: 0.6925
# Epoch 67/150
#
# Epoch 00067: val_loss improved from 0.77690 to 0.77615, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 22s - loss: 0.6881 - accuracy: 0.7044 - val_loss: 0.7761 - val_accuracy: 0.6915
# Epoch 68/150
#
# Epoch 00068: val_loss improved from 0.77615 to 0.77210, saving model to ./models_saved/model_d_conv1d_mfcc13_pol.h5
# 1217/1217 - 23s - loss: 0.6861 - accuracy: 0.7066 - val_loss: 0.7721 - val_accuracy: 0.6931

# %%
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
score,acc = model.evaluate(X_test, y_test, verbose = 2, batch_size = batch_size)
print("score: %.2f" % (score))
print("acc: %.2f" % (acc))
# Out:
# 305/305 - 1s - loss: 0.7796 - accuracy: 0.6931
# score: 0.78
# acc: 0.69

# %%
# load labels
with open('./Data_Array_Storage/labels_mfcc13_axis0_pol.pkl', 'rb') as f:
    lb = pickle.load(f)

# %%
# error analysis

preds = model.predict(X_test, 
                         batch_size=batch_size, 
                         verbose=1)

preds=preds.argmax(axis=1)
preds
# Out:
# 305/305 [==============================] - 1s 3ms/step
# array([0, 0, 0, ..., 0, 0, 0])

# %%
# predictions 
preds = preds.astype(int).flatten()
preds = (lb.inverse_transform((preds)))
preds = pd.DataFrame({'predictedvalues': preds})

# Actual labels
actual = y_test.argmax(axis=1)
actual = actual.astype(int).flatten()
actual = (lb.inverse_transform((actual)))
actual = pd.DataFrame({'actualvalues': actual})

# Lets combined both of them into a single dataframe
finaldf = actual.join(preds)
finaldf[150:180]
# Out:
#     actualvalues predictedvalues
# 150     negative        negative
# 151     negative        negative
# 152     negative        negative
# 153     negative        negative
# 154      neutral        negative
# 155     negative        negative
# 156     negative        negative
# 157     negative        negative
# 158     negative        negative
# 159     negative        negative
# 160     negative        negative
# 161     negative        negative
# 162     negative        negative
# 163     negative        negative
# 164     negative        negative
# 165     negative        negative
# 166     negative        negative
# 167      neutral         neutral
# 168      neutral        negative
# 169     negative        negative
# 170      neutral        negative
# 171      neutral        negative
# 172      neutral         neutral
# 173     negative        negative
# 174     negative        negative
# 175     negative        negative
# 176      neutral        negative
# 177     positive        negative
# 178     negative        negative
# 179      neutral        negative

# %%
# the confusion matrix heat map plot
def print_confusion_matrix(confusion_matrix, class_names, figsize = (10,7), fontsize=14):
    """Prints a confusion matrix, as returned by sklearn.metrics.confusion_matrix, as a heatmap.
    
    Arguments
    ---------
    confusion_matrix: numpy.ndarray
        The numpy.ndarray object returned from a call to sklearn.metrics.confusion_matrix. 
        Similarly constructed ndarrays can also be used.
    class_names: list
        An ordered list of class names, in the order they index the given confusion matrix.
    figsize: tuple
        A 2-long tuple, the first value determining the horizontal size of the ouputted figure,
        the second determining the vertical size. Defaults to (10,7).
    fontsize: int
        Font size for axes labels. Defaults to 14.
        
    Returns
    -------
    matplotlib.figure.Figure
        The resulting confusion matrix figure
    """
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names, columns=class_names, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
        
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
# Get the predictions file 
# finaldf = pd.read_csv("Predictions.csv")
classes = finaldf.actualvalues.unique()
classes.sort()    

# Confusion matrix 
c = confusion_matrix(finaldf.actualvalues, finaldf.predictedvalues)
print(accuracy_score(finaldf.actualvalues, finaldf.predictedvalues))
print_confusion_matrix(c, class_names = classes)
# Out:
# 0.6931140801644399

# %%
# Classification report 
classes = finaldf.actualvalues.unique()
classes.sort()    
print(classification_report(finaldf.actualvalues, finaldf.predictedvalues, target_names=classes))
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.69      0.97      0.80      3070
#      neutral       0.68      0.15      0.24       748
#     positive       0.76      0.28      0.41      1047
#
#     accuracy                           0.69      4865
#    macro avg       0.71      0.47      0.49      4865
# weighted avg       0.70      0.69      0.63      4865
