# %%
'''
Creating to run Model D Conv1d_mfcc13
different layer system
full mfcc 13 features
Created on 2020.12.11
Label: Emotion

'''
# libraries
import numpy as np
import pandas as pd
import pickle
import seaborn as sns
import tensorflow as tf

from tensorflow.keras.layers import Dense, Dropout, Flatten, Input
from tensorflow.keras.layers import Activation, BatchNormalization
from tensorflow.keras.layers import Conv1D, Conv2D, LSTM
from tensorflow.keras.layers import AveragePooling1D, GlobalAveragePooling2D, MaxPooling1D
from tensorflow.keras.models import Model, model_from_json, Sequential

# added this to plot
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
# load datasets

# assigning the pickle files
with open('./Data_Array_Storage/X_train_mfcc13_axis0_emo.pkl', 'rb') as f:
    X_train = pickle.load(f)

with open('./Data_Array_Storage/X_test_mfcc13_axis0_emo.pkl', 'rb') as f:
    X_test = pickle.load(f)

with open('./Data_Array_Storage/y_train_mfcc13_axis0_emo.pkl', 'rb') as f:
    y_train = pickle.load(f)

with open('./Data_Array_Storage/y_test_mfcc13_axis0_emo.pkl', 'rb') as f:
    y_test = pickle.load(f)
    
print('dataset loaded')
# Out:
# dataset loaded

# %%
# input shape
input_shape = (X_train.shape[1], X_train.shape[2])
print(input_shape)
# Out:
# (216, 13)

# %%
def model_d_conv1d(input_shape):
    model = Sequential()
    model.add(Conv1D(32, 3, padding='same',input_shape=input_shape))  # X_train.shape[1] = No. of Columns (216)
    model.add(Activation('relu'))
    model.add(Conv1D(32, 3, padding='same'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.25))
    model.add(MaxPooling1D(pool_size=(3)))
    model.add(Conv1D(64, 3, padding='same'))
    model.add(Activation('relu'))
    model.add(Conv1D(64, 3, padding='same'))
    model.add(Dropout(0.25))
    model.add(MaxPooling1D(pool_size=(3))) # added drop out and maxpooling layer on 20201209 at 1330
    model.add(Activation('relu'))
    model.add(Conv1D(64, 3, padding='same'))
    model.add(Activation('relu'))
    model.add(Conv1D(64, 3, padding='same'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.25))
    model.add(MaxPooling1D(pool_size=(3)))
    model.add(Conv1D(128, 3, padding='same'))
    model.add(Activation('relu'))
    model.add(Conv1D(128, 3, padding='same'))
    model.add(Activation('relu'))
    model.add(Conv1D(256, 3, padding='same'))
    model.add(Activation('relu'))
#     model.add(LSTM(64))
    model.add(Flatten())
    model.add(Dense(7)) # Target class number
    model.add(Activation('softmax'))
    
    # model optimizer
#     model = model_d_conv1d(input_shape)
    optimizer = tf.keras.optimizers.RMSprop(lr=0.000001, decay=1e-6)
    
    # compile model
    model.compile(loss='categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])

    return model

# %%
def model_d_conv1d_flip(input_shape):
    model = Sequential()
    model.add(Conv1D(256, 3, padding='same',input_shape=input_shape))  # X_train.shape[1] = No. of Columns (216)
    model.add(Activation('relu'))
    model.add(Conv1D(256, 3, padding='same'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.25))
    model.add(MaxPooling1D(pool_size=(3)))
    model.add(Conv1D(128, 3, padding='same'))
    model.add(Activation('relu'))
    model.add(Conv1D(128, 3, padding='same'))
    model.add(Dropout(0.25))
    model.add(MaxPooling1D(pool_size=(3))) # added drop out and maxpooling layer on 20201209 at 1330
    model.add(Activation('relu'))
    model.add(Conv1D(128, 3, padding='same'))
    model.add(Activation('relu'))
    model.add(Conv1D(128, 3, padding='same'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.25))
    model.add(MaxPooling1D(pool_size=(3)))
    model.add(Conv1D(64, 3, padding='same'))
    model.add(Activation('relu'))
    model.add(Conv1D(64, 3, padding='same'))
    model.add(Activation('relu'))
    model.add(Conv1D(32, 3, padding='same'))
    model.add(Activation('relu'))
    model.add(Flatten())
    model.add(Dense(3)) # Target class number
    model.add(Activation('softmax'))
    
    # model optimizer
#     model = model_d_conv1d(input_shape)
    optimizer = tf.keras.optimizers.RMSprop(lr=0.000001, decay=1e-6)
    
    # compile model
    model.compile(loss='categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])

    return model

# %%
# load model and input shape
# from models import model_d_conv1d

# model = model_d_conv1d_flip(input_shape)
model = model_d_conv1d(input_shape)
# optimizer = tf.keras.optimizers.RMSprop(lr=0.000001, decay=1e-6)

print('input shape, model, optimizer loaded')

model.summary()
# Out:
# input shape, model, optimizer loaded
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_9 (Conv1D)            (None, 216, 32)           1280
# _________________________________________________________________
# activation_10 (Activation)   (None, 216, 32)           0
# _________________________________________________________________
# conv1d_10 (Conv1D)           (None, 216, 32)           3104
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 216, 32)           128
# _________________________________________________________________
# activation_11 (Activation)   (None, 216, 32)           0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 216, 32)           0
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 72, 32)            0
# _________________________________________________________________
# conv1d_11 (Conv1D)           (None, 72, 64)            6208
# _________________________________________________________________
# activation_12 (Activation)   (None, 72, 64)            0
# _________________________________________________________________
# conv1d_12 (Conv1D)           (None, 72, 64)            12352
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 72, 64)            0
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 24, 64)            0
# _________________________________________________________________
# activation_13 (Activation)   (None, 24, 64)            0
# _________________________________________________________________
# conv1d_13 (Conv1D)           (None, 24, 64)            12352
# _________________________________________________________________
# activation_14 (Activation)   (None, 24, 64)            0
# _________________________________________________________________
# conv1d_14 (Conv1D)           (None, 24, 64)            12352
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 24, 64)            256
# _________________________________________________________________
# activation_15 (Activation)   (None, 24, 64)            0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 24, 64)            0
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 8, 64)             0
# _________________________________________________________________
# conv1d_15 (Conv1D)           (None, 8, 128)            24704
# _________________________________________________________________
# activation_16 (Activation)   (None, 8, 128)            0
# _________________________________________________________________
# conv1d_16 (Conv1D)           (None, 8, 128)            49280
# _________________________________________________________________
# activation_17 (Activation)   (None, 8, 128)            0
# _________________________________________________________________
# conv1d_17 (Conv1D)           (None, 8, 256)            98560
# _________________________________________________________________
# activation_18 (Activation)   (None, 8, 256)            0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 7)                 14343
# _________________________________________________________________
# activation_19 (Activation)   (None, 7)                 0
# =================================================================
# Total params: 234,919
# Trainable params: 234,727
# Non-trainable params: 192
# _________________________________________________________________

# %%
# callback list: ModelCheckpoint, reduceLROnPlat, EarlyStopping
# checkpoint_path = "./models_saved/model_d_conv1d_v3.h5"

checkpoint_path = "./models_saved/model_d_conv1d_mfcc13_emo.h5"

# Create a callback that saves the model's weights
callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=False,
                                                 save_best_only=True,
                                                 verbose=1), # 1 tells your which epoch is saving
#                                                  monitor='val_categorical_accuracy',  # added for emo1d
#                                                  mode='max'), # added for emo1d
               tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', # changed from 'val_accuracy', 'val_loss'
                                                patience=5, 
                                                restore_best_weights=True),
#                                                 verbose = 1, # added verbose for emo1d
#                                                 mode = 'min'), # added for emo1d
               tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', 
                                                    patience=2, 
                                                    factor=0.5, 
                                                    min_lr=0.000001, 
                                                    verbose=1)]

print('callbacks and checkpoints set')
# Out:
# callbacks and checkpoints set

# %%
batch_size = 64

model_history=model.fit(X_train, 
                        y_train,
                        batch_size=batch_size,
                        epochs=150,
                        validation_data=(X_test, y_test),
                        verbose=2,
                        callbacks=callbacks)
# Out:
# Epoch 1/150
#
# Epoch 00001: val_loss improved from inf to 1.94014, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 9s - loss: 1.9926 - accuracy: 0.1631 - val_loss: 1.9401 - val_accuracy: 0.1704
# Epoch 2/150
#
# Epoch 00002: val_loss improved from 1.94014 to 1.92951, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 10s - loss: 1.9506 - accuracy: 0.1720 - val_loss: 1.9295 - val_accuracy: 0.1762
# Epoch 3/150
#
# Epoch 00003: val_loss improved from 1.92951 to 1.91996, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 9s - loss: 1.9244 - accuracy: 0.1869 - val_loss: 1.9200 - val_accuracy: 0.1786
# Epoch 4/150
#
# Epoch 00004: val_loss improved from 1.91996 to 1.91222, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 10s - loss: 1.9104 - accuracy: 0.1921 - val_loss: 1.9122 - val_accuracy: 0.1891
# Epoch 5/150
#
# Epoch 00005: val_loss improved from 1.91222 to 1.90535, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 9s - loss: 1.8980 - accuracy: 0.2029 - val_loss: 1.9054 - val_accuracy: 0.2016
# Epoch 6/150
#
# Epoch 00006: val_loss improved from 1.90535 to 1.89911, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 10s - loss: 1.8882 - accuracy: 0.2191 - val_loss: 1.8991 - val_accuracy: 0.2080
# Epoch 7/150
#
# Epoch 00007: val_loss improved from 1.89911 to 1.89263, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 10s - loss: 1.8787 - accuracy: 0.2293 - val_loss: 1.8926 - val_accuracy: 0.2129
# Epoch 8/150
#
# Epoch 00008: val_loss improved from 1.89263 to 1.88660, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 10s - loss: 1.8689 - accuracy: 0.2409 - val_loss: 1.8866 - val_accuracy: 0.2271
# Epoch 9/150
#
# Epoch 00009: val_loss improved from 1.88660 to 1.88036, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 10s - loss: 1.8589 - accuracy: 0.2508 - val_loss: 1.8804 - val_accuracy: 0.2325
# Epoch 10/150
#
# Epoch 00010: val_loss improved from 1.88036 to 1.87447, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 10s - loss: 1.8504 - accuracy: 0.2584 - val_loss: 1.8745 - val_accuracy: 0.2413
# Epoch 11/150
#
# Epoch 00011: val_loss improved from 1.87447 to 1.86731, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 10s - loss: 1.8415 - accuracy: 0.2675 - val_loss: 1.8673 - val_accuracy: 0.2479
# Epoch 12/150
#
# Epoch 00012: val_loss improved from 1.86731 to 1.86108, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 10s - loss: 1.8310 - accuracy: 0.2741 - val_loss: 1.8611 - val_accuracy: 0.2541
# Epoch 13/150
#
# Epoch 00013: val_loss improved from 1.86108 to 1.85403, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 10s - loss: 1.8187 - accuracy: 0.2850 - val_loss: 1.8540 - val_accuracy: 0.2608
# Epoch 14/150
#
# Epoch 00014: val_loss improved from 1.85403 to 1.84671, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 10s - loss: 1.8089 - accuracy: 0.2917 - val_loss: 1.8467 - val_accuracy: 0.2701
# Epoch 15/150
#
# Epoch 00015: val_loss improved from 1.84671 to 1.83962, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 10s - loss: 1.7966 - accuracy: 0.2985 - val_loss: 1.8396 - val_accuracy: 0.2734
# Epoch 16/150
#
# Epoch 00016: val_loss improved from 1.83962 to 1.83271, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 10s - loss: 1.7861 - accuracy: 0.3047 - val_loss: 1.8327 - val_accuracy: 0.2779
# Epoch 17/150
#
# Epoch 00017: val_loss improved from 1.83271 to 1.82372, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 9s - loss: 1.7755 - accuracy: 0.3055 - val_loss: 1.8237 - val_accuracy: 0.2835
# Epoch 18/150
#
# Epoch 00018: val_loss improved from 1.82372 to 1.81594, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 9s - loss: 1.7623 - accuracy: 0.3156 - val_loss: 1.8159 - val_accuracy: 0.2874
# Epoch 19/150
#
# Epoch 00019: val_loss improved from 1.81594 to 1.80988, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 9s - loss: 1.7503 - accuracy: 0.3226 - val_loss: 1.8099 - val_accuracy: 0.2888
# Epoch 20/150
#
# Epoch 00020: val_loss improved from 1.80988 to 1.80030, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 10s - loss: 1.7391 - accuracy: 0.3265 - val_loss: 1.8003 - val_accuracy: 0.2962
# Epoch 21/150
#
# Epoch 00021: val_loss improved from 1.80030 to 1.79208, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 10s - loss: 1.7236 - accuracy: 0.3355 - val_loss: 1.7921 - val_accuracy: 0.3024
# Epoch 22/150
#
# Epoch 00022: val_loss improved from 1.79208 to 1.78404, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 10s - loss: 1.7135 - accuracy: 0.3367 - val_loss: 1.7840 - val_accuracy: 0.3038
# Epoch 23/150
#
# Epoch 00023: val_loss improved from 1.78404 to 1.77631, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 10s - loss: 1.7027 - accuracy: 0.3379 - val_loss: 1.7763 - val_accuracy: 0.3038
# Epoch 24/150
#
# Epoch 00024: val_loss improved from 1.77631 to 1.76769, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 10s - loss: 1.6896 - accuracy: 0.3443 - val_loss: 1.7677 - val_accuracy: 0.3067
# Epoch 25/150
#
# Epoch 00025: val_loss improved from 1.76769 to 1.76011, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 13s - loss: 1.6787 - accuracy: 0.3490 - val_loss: 1.7601 - val_accuracy: 0.3085
# Epoch 26/150
#
# Epoch 00026: val_loss improved from 1.76011 to 1.75477, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 14s - loss: 1.6699 - accuracy: 0.3492 - val_loss: 1.7548 - val_accuracy: 0.3069
# Epoch 27/150
#
# Epoch 00027: val_loss improved from 1.75477 to 1.74648, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 14s - loss: 1.6574 - accuracy: 0.3576 - val_loss: 1.7465 - val_accuracy: 0.3112
# Epoch 28/150
#
# Epoch 00028: val_loss improved from 1.74648 to 1.73775, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 14s - loss: 1.6500 - accuracy: 0.3590 - val_loss: 1.7377 - val_accuracy: 0.3153
# Epoch 29/150
#
# Epoch 00029: val_loss improved from 1.73775 to 1.73192, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 14s - loss: 1.6398 - accuracy: 0.3597 - val_loss: 1.7319 - val_accuracy: 0.3145
# Epoch 30/150
#
# Epoch 00030: val_loss improved from 1.73192 to 1.72798, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 16s - loss: 1.6324 - accuracy: 0.3619 - val_loss: 1.7280 - val_accuracy: 0.3155
# Epoch 31/150
#
# Epoch 00031: val_loss improved from 1.72798 to 1.72195, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 15s - loss: 1.6249 - accuracy: 0.3693 - val_loss: 1.7220 - val_accuracy: 0.3178
# Epoch 32/150
#
# Epoch 00032: val_loss improved from 1.72195 to 1.71462, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 15s - loss: 1.6161 - accuracy: 0.3718 - val_loss: 1.7146 - val_accuracy: 0.3219
# Epoch 33/150
#
# Epoch 00033: val_loss improved from 1.71462 to 1.71197, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 13s - loss: 1.6076 - accuracy: 0.3732 - val_loss: 1.7120 - val_accuracy: 0.3223
# Epoch 34/150
#
# Epoch 00034: val_loss improved from 1.71197 to 1.70440, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 12s - loss: 1.6016 - accuracy: 0.3741 - val_loss: 1.7044 - val_accuracy: 0.3264
# Epoch 35/150
#
# Epoch 00035: val_loss improved from 1.70440 to 1.70138, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 11s - loss: 1.5939 - accuracy: 0.3785 - val_loss: 1.7014 - val_accuracy: 0.3276
# Epoch 36/150
#
# Epoch 00036: val_loss improved from 1.70138 to 1.69644, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 11s - loss: 1.5874 - accuracy: 0.3799 - val_loss: 1.6964 - val_accuracy: 0.3276
# Epoch 37/150
#
# Epoch 00037: val_loss improved from 1.69644 to 1.69079, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 11s - loss: 1.5806 - accuracy: 0.3842 - val_loss: 1.6908 - val_accuracy: 0.3318
# Epoch 38/150
#
# Epoch 00038: val_loss improved from 1.69079 to 1.68648, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 11s - loss: 1.5745 - accuracy: 0.3886 - val_loss: 1.6865 - val_accuracy: 0.3330
# Epoch 39/150
#
# Epoch 00039: val_loss improved from 1.68648 to 1.68298, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 11s - loss: 1.5689 - accuracy: 0.3892 - val_loss: 1.6830 - val_accuracy: 0.3359
# Epoch 40/150
#
# Epoch 00040: val_loss improved from 1.68298 to 1.67845, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 11s - loss: 1.5629 - accuracy: 0.3935 - val_loss: 1.6784 - val_accuracy: 0.3355
# Epoch 41/150
#
# Epoch 00041: val_loss improved from 1.67845 to 1.67614, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 11s - loss: 1.5594 - accuracy: 0.3917 - val_loss: 1.6761 - val_accuracy: 0.3373
# Epoch 42/150
#
# Epoch 00042: val_loss improved from 1.67614 to 1.67508, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 10s - loss: 1.5521 - accuracy: 0.3953 - val_loss: 1.6751 - val_accuracy: 0.3371
# Epoch 43/150
#
# Epoch 00043: val_loss improved from 1.67508 to 1.66968, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 10s - loss: 1.5495 - accuracy: 0.3950 - val_loss: 1.6697 - val_accuracy: 0.3398
# Epoch 44/150
#
# Epoch 00044: val_loss improved from 1.66968 to 1.66856, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 10s - loss: 1.5445 - accuracy: 0.3997 - val_loss: 1.6686 - val_accuracy: 0.3398
# Epoch 45/150
#
# Epoch 00045: val_loss improved from 1.66856 to 1.66736, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 10s - loss: 1.5397 - accuracy: 0.3979 - val_loss: 1.6674 - val_accuracy: 0.3390
# Epoch 46/150
#
# Epoch 00046: val_loss improved from 1.66736 to 1.66373, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 10s - loss: 1.5356 - accuracy: 0.4054 - val_loss: 1.6637 - val_accuracy: 0.3412
# Epoch 47/150
#
# Epoch 00047: val_loss improved from 1.66373 to 1.66059, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 10s - loss: 1.5299 - accuracy: 0.4024 - val_loss: 1.6606 - val_accuracy: 0.3443
# Epoch 48/150
#
# Epoch 00048: val_loss improved from 1.66059 to 1.65709, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 10s - loss: 1.5257 - accuracy: 0.4047 - val_loss: 1.6571 - val_accuracy: 0.3451
# Epoch 49/150
#
# Epoch 00049: val_loss improved from 1.65709 to 1.65614, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 10s - loss: 1.5229 - accuracy: 0.4065 - val_loss: 1.6561 - val_accuracy: 0.3431
# Epoch 50/150
#
# Epoch 00050: val_loss improved from 1.65614 to 1.65480, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 11s - loss: 1.5184 - accuracy: 0.4097 - val_loss: 1.6548 - val_accuracy: 0.3429
# Epoch 51/150
#
# Epoch 00051: val_loss improved from 1.65480 to 1.65122, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 10s - loss: 1.5138 - accuracy: 0.4110 - val_loss: 1.6512 - val_accuracy: 0.3457
# Epoch 52/150
#
# Epoch 00052: val_loss improved from 1.65122 to 1.64945, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 10s - loss: 1.5098 - accuracy: 0.4117 - val_loss: 1.6494 - val_accuracy: 0.3472
# Epoch 53/150
#
# Epoch 00053: val_loss improved from 1.64945 to 1.64350, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 10s - loss: 1.5044 - accuracy: 0.4151 - val_loss: 1.6435 - val_accuracy: 0.3501
# Epoch 54/150
#
# Epoch 00054: val_loss improved from 1.64350 to 1.64122, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 10s - loss: 1.5005 - accuracy: 0.4150 - val_loss: 1.6412 - val_accuracy: 0.3517
# Epoch 55/150
#
# Epoch 00055: val_loss did not improve from 1.64122
# 305/305 - 10s - loss: 1.4984 - accuracy: 0.4190 - val_loss: 1.6426 - val_accuracy: 0.3484
# Epoch 56/150
#
# Epoch 00056: val_loss improved from 1.64122 to 1.63979, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 11s - loss: 1.4935 - accuracy: 0.4217 - val_loss: 1.6398 - val_accuracy: 0.3503
# Epoch 57/150
#
# Epoch 00057: val_loss did not improve from 1.63979
# 305/305 - 15s - loss: 1.4920 - accuracy: 0.4232 - val_loss: 1.6417 - val_accuracy: 0.3503
# Epoch 58/150
#
# Epoch 00058: val_loss improved from 1.63979 to 1.63728, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 14s - loss: 1.4864 - accuracy: 0.4242 - val_loss: 1.6373 - val_accuracy: 0.3523
# Epoch 59/150
#
# Epoch 00059: val_loss improved from 1.63728 to 1.63500, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 14s - loss: 1.4830 - accuracy: 0.4254 - val_loss: 1.6350 - val_accuracy: 0.3517
# Epoch 60/150
#
# Epoch 00060: val_loss improved from 1.63500 to 1.63461, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 13s - loss: 1.4792 - accuracy: 0.4272 - val_loss: 1.6346 - val_accuracy: 0.3527
# Epoch 61/150
#
# Epoch 00061: val_loss did not improve from 1.63461
# 305/305 - 16s - loss: 1.4784 - accuracy: 0.4242 - val_loss: 1.6351 - val_accuracy: 0.3521
# Epoch 62/150
#
# Epoch 00062: val_loss improved from 1.63461 to 1.63266, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 18s - loss: 1.4706 - accuracy: 0.4302 - val_loss: 1.6327 - val_accuracy: 0.3529
# Epoch 63/150
#
# Epoch 00063: val_loss improved from 1.63266 to 1.62794, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 18s - loss: 1.4691 - accuracy: 0.4290 - val_loss: 1.6279 - val_accuracy: 0.3556
# Epoch 64/150
#
# Epoch 00064: val_loss improved from 1.62794 to 1.62525, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 19s - loss: 1.4692 - accuracy: 0.4293 - val_loss: 1.6252 - val_accuracy: 0.3570
# Epoch 65/150
#
# Epoch 00065: val_loss did not improve from 1.62525
# 305/305 - 18s - loss: 1.4609 - accuracy: 0.4335 - val_loss: 1.6272 - val_accuracy: 0.3542
# Epoch 66/150
#
# Epoch 00066: val_loss did not improve from 1.62525
# 305/305 - 17s - loss: 1.4582 - accuracy: 0.4319 - val_loss: 1.6259 - val_accuracy: 0.3542
# Epoch 67/150
#
# Epoch 00067: val_loss improved from 1.62525 to 1.62101, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 17s - loss: 1.4592 - accuracy: 0.4326 - val_loss: 1.6210 - val_accuracy: 0.3585
# Epoch 68/150
#
# Epoch 00068: val_loss improved from 1.62101 to 1.61961, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 16s - loss: 1.4565 - accuracy: 0.4347 - val_loss: 1.6196 - val_accuracy: 0.3589
# Epoch 69/150
#
# Epoch 00069: val_loss did not improve from 1.61961
# 305/305 - 18s - loss: 1.4534 - accuracy: 0.4345 - val_loss: 1.6207 - val_accuracy: 0.3587
# Epoch 70/150
#
# Epoch 00070: val_loss improved from 1.61961 to 1.61697, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 17s - loss: 1.4509 - accuracy: 0.4357 - val_loss: 1.6170 - val_accuracy: 0.3624
# Epoch 71/150
#
# Epoch 00071: val_loss improved from 1.61697 to 1.61410, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 18s - loss: 1.4479 - accuracy: 0.4410 - val_loss: 1.6141 - val_accuracy: 0.3628
# Epoch 72/150
#
# Epoch 00072: val_loss did not improve from 1.61410
# 305/305 - 18s - loss: 1.4441 - accuracy: 0.4406 - val_loss: 1.6158 - val_accuracy: 0.3626
# Epoch 73/150
#
# Epoch 00073: val_loss improved from 1.61410 to 1.61266, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 20s - loss: 1.4412 - accuracy: 0.4448 - val_loss: 1.6127 - val_accuracy: 0.3626
# Epoch 74/150
#
# Epoch 00074: val_loss improved from 1.61266 to 1.61103, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 19s - loss: 1.4357 - accuracy: 0.4449 - val_loss: 1.6110 - val_accuracy: 0.3644
# Epoch 75/150
#
# Epoch 00075: val_loss did not improve from 1.61103
# 305/305 - 18s - loss: 1.4319 - accuracy: 0.4458 - val_loss: 1.6170 - val_accuracy: 0.3591
# Epoch 76/150
#
# Epoch 00076: val_loss improved from 1.61103 to 1.60791, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 18s - loss: 1.4322 - accuracy: 0.4444 - val_loss: 1.6079 - val_accuracy: 0.3653
# Epoch 77/150
#
# Epoch 00077: val_loss did not improve from 1.60791
# 305/305 - 18s - loss: 1.4302 - accuracy: 0.4450 - val_loss: 1.6079 - val_accuracy: 0.3630
# Epoch 78/150
#
# Epoch 00078: val_loss improved from 1.60791 to 1.60377, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 18s - loss: 1.4259 - accuracy: 0.4488 - val_loss: 1.6038 - val_accuracy: 0.3663
# Epoch 79/150
#
# Epoch 00079: val_loss did not improve from 1.60377
# 305/305 - 18s - loss: 1.4263 - accuracy: 0.4455 - val_loss: 1.6080 - val_accuracy: 0.3634
# Epoch 80/150
#
# Epoch 00080: val_loss did not improve from 1.60377
# 305/305 - 17s - loss: 1.4191 - accuracy: 0.4532 - val_loss: 1.6071 - val_accuracy: 0.3624
# Epoch 81/150
#
# Epoch 00081: val_loss did not improve from 1.60377
# 305/305 - 17s - loss: 1.4191 - accuracy: 0.4526 - val_loss: 1.6043 - val_accuracy: 0.3632
# Epoch 82/150
#
# Epoch 00082: val_loss improved from 1.60377 to 1.60188, saving model to ./models_saved/model_d_conv1d_mfcc13_emo.h5
# 305/305 - 19s - loss: 1.4184 - accuracy: 0.4464 - val_loss: 1.6019 - val_accuracy: 0.3646
# Epoch 83/150
#
# Epoch 00083: val_loss did not improve from 1.60188
# 305/305 - 18s - loss: 1.4174 - accuracy: 0.4563 - val_loss: 1.6028 - val_accuracy: 0.3628

# %%
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
score,acc = model.evaluate(X_test, y_test, verbose = 2, batch_size = batch_size)
print("score: %.2f" % (score))
print("acc: %.2f" % (acc))
# Out:
# 77/77 - 1s - loss: 1.6038 - accuracy: 0.3663
# score: 1.60
# acc: 0.37

# %%
# load labels
with open('./Data_Array_Storage/labels_mfcc13_axis0_emo.pkl', 'rb') as f:
    lb = pickle.load(f)

# %%
# error analysis

preds = model.predict(X_test, 
                         batch_size=batch_size, 
                         verbose=1)

preds=preds.argmax(axis=1)
preds
# Out:
# 77/77 [==============================] - 1s 8ms/step
# array([5, 4, 5, ..., 1, 1, 5])

# %%
# predictions 
preds = preds.astype(int).flatten()
preds = (lb.inverse_transform((preds)))
preds = pd.DataFrame({'predictedvalues': preds})

# Actual labels
actual = y_test.argmax(axis=1)
actual = actual.astype(int).flatten()
actual = (lb.inverse_transform((actual)))
actual = pd.DataFrame({'actualvalues': actual})

# Lets combined both of them into a single dataframe
finaldf = actual.join(preds)
finaldf[150:180]
# Out:
#     actualvalues predictedvalues
# 150          sad             sad
# 151      disgust             sad
# 152        angry           angry
# 153      disgust            fear
# 154      neutral         neutral
# 155      disgust         disgust
# 156      disgust         disgust
# 157         fear             sad
# 158        angry         neutral
# 159      disgust             sad
# 160         fear         neutral
# 161         fear            fear
# 162         fear            fear
# 163         fear         neutral
# 164        angry         neutral
# 165      disgust         disgust
# 166      disgust             sad
# 167      neutral             sad
# 168      neutral         neutral
# 169      disgust             sad
# 170      neutral         neutral
# 171      neutral         neutral
# 172      neutral         neutral
# 173        angry           happy
# 174        angry           angry
# 175      disgust         neutral
# 176      neutral             sad
# 177     surprise           happy
# 178         fear            fear
# 179      neutral         neutral

# %%
# the confusion matrix heat map plot
def print_confusion_matrix(confusion_matrix, class_names, figsize = (10,7), fontsize=14):
    """Prints a confusion matrix, as returned by sklearn.metrics.confusion_matrix, as a heatmap.
    
    Arguments
    ---------
    confusion_matrix: numpy.ndarray
        The numpy.ndarray object returned from a call to sklearn.metrics.confusion_matrix. 
        Similarly constructed ndarrays can also be used.
    class_names: list
        An ordered list of class names, in the order they index the given confusion matrix.
    figsize: tuple
        A 2-long tuple, the first value determining the horizontal size of the ouputted figure,
        the second determining the vertical size. Defaults to (10,7).
    fontsize: int
        Font size for axes labels. Defaults to 14.
        
    Returns
    -------
    matplotlib.figure.Figure
        The resulting confusion matrix figure
    """
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names, columns=class_names, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
        
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
# Get the predictions file 
# finaldf = pd.read_csv("Predictions.csv")
classes = finaldf.actualvalues.unique()
classes.sort()    

# Confusion matrix 
c = confusion_matrix(finaldf.actualvalues, finaldf.predictedvalues)
print(accuracy_score(finaldf.actualvalues, finaldf.predictedvalues))
print_confusion_matrix(c, class_names = classes)
# Out:
# 0.36628982528263104

# %%
# Classification report 
classes = finaldf.actualvalues.unique()
classes.sort()    
print(classification_report(finaldf.actualvalues, finaldf.predictedvalues, target_names=classes))
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.62      0.27      0.38       771
#      disgust       0.37      0.27      0.31       808
#         fear       0.39      0.31      0.35       751
#        happy       0.34      0.24      0.28       785
#      neutral       0.29      0.50      0.37       748
#          sad       0.37      0.74      0.49       740
#     surprise       0.44      0.03      0.05       262
#
#     accuracy                           0.37      4865
#    macro avg       0.40      0.34      0.32      4865
# weighted avg       0.40      0.37      0.35      4865
