# %%
import numpy as np
import pandas as pd
import pickle
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
# calling the Data Path file
ref_data_path = pd.read_csv('./Data_Array_Storage/Data_path.csv')

# %%
# assigning the pickle files
with open('./Data_Array_Storage/data_features.pkl', 'rb') as f:
    df_features = pickle.load(f)

# %%
df_features
# Out:
#                                                  feature
# 0      [-23.589672, -24.579994, -22.594236, -21.48121...
# 1      [-23.371296, -24.25871, -24.391258, -23.972637...
# 2      [-3.8807042, -5.170106, -8.079337, -7.4936037,...
# 3      [-7.7042017, -6.6937556, -7.5397215, -8.864785...
# 4      [-4.9374456, -5.962815, -9.859099, -8.692252, ...
# ...                                                  ...
# 12171  [-18.833895, -16.35894, -16.981724, -16.507805...
# 12172  [-20.607792, -19.01767, -19.228441, -20.90208,...
# 12173  [-21.098043, -20.155556, -19.352476, -20.54941...
# 12174  [-21.708447, -20.894457, -21.9294, -22.72151, ...
# 12175  [-14.367807, -15.577645, -16.614231, -17.75939...
#
# [12162 rows x 1 columns]

# %%
# saving df_features_noise as pickle file
with open('./Data_Array_Storage/data_features_noise.pkl', 'rb') as f:
    df_features_noise = pickle.load(f)

# %%
df_features_noise
# Out:
#                                                  feature
# 0      [-15.047303001991889, -12.454846146787027, -11...
# 1      [-15.311536209703986, -15.019214957419159, -15...
# 2      [1.000180813967013, -0.21367674794390148, -3.4...
# 3      [-4.583707788699725, -3.315573058318937, -4.20...
# 4      [-0.1660587437111446, -0.8291181490649677, -3....
# ...                                                  ...
# 12171  [-15.891046503738957, -13.249578076692925, -14...
# 12172  [-14.340122906275589, -13.570734896054937, -14...
# 12173  [-19.785674805598042, -19.051237007056873, -18...
# 12174  [-14.755576218823165, -14.559496430857745, -15...
# 12175  [-12.338572218416768, -13.298607899945956, -14...
#
# [12162 rows x 1 columns]

# %%
# combining dataframes
df_path_features = pd.concat([ref_data_path,pd.DataFrame(df_features)],axis=1)
df_path_features_noise = pd.concat([ref_data_path,pd.DataFrame(df_features_noise)],axis=1)

# %%
df_path_features
# Out:
#        gender   emotion   label_emotion  polarity   label_polarity source  \
# 0        male       sad        male_sad  negative    male_negative  SAVEE
# 1        male       sad        male_sad  negative    male_negative  SAVEE
# 2        male   neutral    male_neutral   neutral     male_neutral  SAVEE
# 3        male  surprise   male_surprise   neutral     male_neutral  SAVEE
# 4        male   neutral    male_neutral   neutral     male_neutral  SAVEE
# ...       ...       ...             ...       ...              ...    ...
# 12171  female   disgust  female_disgust  negative  female_negative  CREMA
# 12172  female      fear     female_fear  negative  female_negative  CREMA
# 12173  female     happy    female_happy  positive  female_positive  CREMA
# 12174  female   neutral  female_neutral   neutral   female_neutral  CREMA
# 12175  female       sad      female_sad  negative  female_negative  CREMA
#
#                                              path  \
# 0                    ./data/savee/ALL/JK_sa01.wav
# 1                    ./data/savee/ALL/JK_sa15.wav
# 2                     ./data/savee/ALL/DC_n13.wav
# 3                    ./data/savee/ALL/DC_su09.wav
# 4                     ./data/savee/ALL/DC_n07.wav
# ...                                           ...
# 12171  ./data/cremad/AudioWAV/1091_WSI_DIS_XX.wav
# 12172  ./data/cremad/AudioWAV/1091_WSI_FEA_XX.wav
# 12173  ./data/cremad/AudioWAV/1091_WSI_HAP_XX.wav
# 12174  ./data/cremad/AudioWAV/1091_WSI_NEU_XX.wav
# 12175  ./data/cremad/AudioWAV/1091_WSI_SAD_XX.wav
#
#                                                  feature
# 0      [-23.589672, -24.579994, -22.594236, -21.48121...
# 1      [-23.371296, -24.25871, -24.391258, -23.972637...
# 2      [-3.8807042, -5.170106, -8.079337, -7.4936037,...
# 3      [-7.7042017, -6.6937556, -7.5397215, -8.864785...
# 4      [-4.9374456, -5.962815, -9.859099, -8.692252, ...
# ...                                                  ...
# 12171  [-18.833895, -16.35894, -16.981724, -16.507805...
# 12172  [-20.607792, -19.01767, -19.228441, -20.90208,...
# 12173  [-21.098043, -20.155556, -19.352476, -20.54941...
# 12174  [-21.708447, -20.894457, -21.9294, -22.72151, ...
# 12175  [-14.367807, -15.577645, -16.614231, -17.75939...
#
# [12176 rows x 8 columns]

# %%
df_path_features_noise
# Out:
#        gender   emotion   label_emotion  polarity   label_polarity source  \
# 0        male       sad        male_sad  negative    male_negative  SAVEE
# 1        male       sad        male_sad  negative    male_negative  SAVEE
# 2        male   neutral    male_neutral   neutral     male_neutral  SAVEE
# 3        male  surprise   male_surprise   neutral     male_neutral  SAVEE
# 4        male   neutral    male_neutral   neutral     male_neutral  SAVEE
# ...       ...       ...             ...       ...              ...    ...
# 12171  female   disgust  female_disgust  negative  female_negative  CREMA
# 12172  female      fear     female_fear  negative  female_negative  CREMA
# 12173  female     happy    female_happy  positive  female_positive  CREMA
# 12174  female   neutral  female_neutral   neutral   female_neutral  CREMA
# 12175  female       sad      female_sad  negative  female_negative  CREMA
#
#                                              path  \
# 0                    ./data/savee/ALL/JK_sa01.wav
# 1                    ./data/savee/ALL/JK_sa15.wav
# 2                     ./data/savee/ALL/DC_n13.wav
# 3                    ./data/savee/ALL/DC_su09.wav
# 4                     ./data/savee/ALL/DC_n07.wav
# ...                                           ...
# 12171  ./data/cremad/AudioWAV/1091_WSI_DIS_XX.wav
# 12172  ./data/cremad/AudioWAV/1091_WSI_FEA_XX.wav
# 12173  ./data/cremad/AudioWAV/1091_WSI_HAP_XX.wav
# 12174  ./data/cremad/AudioWAV/1091_WSI_NEU_XX.wav
# 12175  ./data/cremad/AudioWAV/1091_WSI_SAD_XX.wav
#
#                                                  feature
# 0      [-15.047303001991889, -12.454846146787027, -11...
# 1      [-15.311536209703986, -15.019214957419159, -15...
# 2      [1.000180813967013, -0.21367674794390148, -3.4...
# 3      [-4.583707788699725, -3.315573058318937, -4.20...
# 4      [-0.1660587437111446, -0.8291181490649677, -3....
# ...                                                  ...
# 12171  [-15.891046503738957, -13.249578076692925, -14...
# 12172  [-14.340122906275589, -13.570734896054937, -14...
# 12173  [-19.785674805598042, -19.051237007056873, -18...
# 12174  [-14.755576218823165, -14.559496430857745, -15...
# 12175  [-12.338572218416768, -13.298607899945956, -14...
#
# [12176 rows x 8 columns]

# %%
df_features_all = pd.concat([df_path_features,df_path_features_noise],axis=0,sort=False) # ,df_speedpitch
df_final = df_features_all.fillna(0)

# %%
df_final
# Out:
#        gender   emotion   label_emotion  polarity   label_polarity source  \
# 0        male       sad        male_sad  negative    male_negative  SAVEE
# 1        male       sad        male_sad  negative    male_negative  SAVEE
# 2        male   neutral    male_neutral   neutral     male_neutral  SAVEE
# 3        male  surprise   male_surprise   neutral     male_neutral  SAVEE
# 4        male   neutral    male_neutral   neutral     male_neutral  SAVEE
# ...       ...       ...             ...       ...              ...    ...
# 12171  female   disgust  female_disgust  negative  female_negative  CREMA
# 12172  female      fear     female_fear  negative  female_negative  CREMA
# 12173  female     happy    female_happy  positive  female_positive  CREMA
# 12174  female   neutral  female_neutral   neutral   female_neutral  CREMA
# 12175  female       sad      female_sad  negative  female_negative  CREMA
#
#                                              path  \
# 0                    ./data/savee/ALL/JK_sa01.wav
# 1                    ./data/savee/ALL/JK_sa15.wav
# 2                     ./data/savee/ALL/DC_n13.wav
# 3                    ./data/savee/ALL/DC_su09.wav
# 4                     ./data/savee/ALL/DC_n07.wav
# ...                                           ...
# 12171  ./data/cremad/AudioWAV/1091_WSI_DIS_XX.wav
# 12172  ./data/cremad/AudioWAV/1091_WSI_FEA_XX.wav
# 12173  ./data/cremad/AudioWAV/1091_WSI_HAP_XX.wav
# 12174  ./data/cremad/AudioWAV/1091_WSI_NEU_XX.wav
# 12175  ./data/cremad/AudioWAV/1091_WSI_SAD_XX.wav
#
#                                                  feature
# 0      [-23.589672, -24.579994, -22.594236, -21.48121...
# 1      [-23.371296, -24.25871, -24.391258, -23.972637...
# 2      [-3.8807042, -5.170106, -8.079337, -7.4936037,...
# 3      [-7.7042017, -6.6937556, -7.5397215, -8.864785...
# 4      [-4.9374456, -5.962815, -9.859099, -8.692252, ...
# ...                                                  ...
# 12171  [-15.891046503738957, -13.249578076692925, -14...
# 12172  [-14.340122906275589, -13.570734896054937, -14...
# 12173  [-19.785674805598042, -19.051237007056873, -18...
# 12174  [-14.755576218823165, -14.559496430857745, -15...
# 12175  [-12.338572218416768, -13.298607899945956, -14...
#
# [24352 rows x 8 columns]

# %%
df_features_all
# Out:
#        gender   emotion   label_emotion  polarity   label_polarity source  \
# 0        male       sad        male_sad  negative    male_negative  SAVEE
# 1        male       sad        male_sad  negative    male_negative  SAVEE
# 2        male   neutral    male_neutral   neutral     male_neutral  SAVEE
# 3        male  surprise   male_surprise   neutral     male_neutral  SAVEE
# 4        male   neutral    male_neutral   neutral     male_neutral  SAVEE
# ...       ...       ...             ...       ...              ...    ...
# 12171  female   disgust  female_disgust  negative  female_negative  CREMA
# 12172  female      fear     female_fear  negative  female_negative  CREMA
# 12173  female     happy    female_happy  positive  female_positive  CREMA
# 12174  female   neutral  female_neutral   neutral   female_neutral  CREMA
# 12175  female       sad      female_sad  negative  female_negative  CREMA
#
#                                              path  \
# 0                    ./data/savee/ALL/JK_sa01.wav
# 1                    ./data/savee/ALL/JK_sa15.wav
# 2                     ./data/savee/ALL/DC_n13.wav
# 3                    ./data/savee/ALL/DC_su09.wav
# 4                     ./data/savee/ALL/DC_n07.wav
# ...                                           ...
# 12171  ./data/cremad/AudioWAV/1091_WSI_DIS_XX.wav
# 12172  ./data/cremad/AudioWAV/1091_WSI_FEA_XX.wav
# 12173  ./data/cremad/AudioWAV/1091_WSI_HAP_XX.wav
# 12174  ./data/cremad/AudioWAV/1091_WSI_NEU_XX.wav
# 12175  ./data/cremad/AudioWAV/1091_WSI_SAD_XX.wav
#
#                                                  feature
# 0      [-23.589672, -24.579994, -22.594236, -21.48121...
# 1      [-23.371296, -24.25871, -24.391258, -23.972637...
# 2      [-3.8807042, -5.170106, -8.079337, -7.4936037,...
# 3      [-7.7042017, -6.6937556, -7.5397215, -8.864785...
# 4      [-4.9374456, -5.962815, -9.859099, -8.692252, ...
# ...                                                  ...
# 12171  [-15.891046503738957, -13.249578076692925, -14...
# 12172  [-14.340122906275589, -13.570734896054937, -14...
# 12173  [-19.785674805598042, -19.051237007056873, -18...
# 12174  [-14.755576218823165, -14.559496430857745, -15...
# 12175  [-12.338572218416768, -13.298607899945956, -14...
#
# [24352 rows x 8 columns]

# %%
# Split between train and test 
X_train, X_test, y_train, y_test = train_test_split(df_final.drop(['gender','emotion','label_emotion','polarity','label_polarity','path','source'],axis=1),
                                                    df_final.polarity,
                                                    test_size=0.25,
                                                    shuffle=True,
                                                    random_state=42)

# %%
X_train
# Out:
#                                                  feature
# 11888  [-2.355693042021739, -5.460588114337696, -10.1...
# 3336   [-17.54205, -20.942657, -27.95588, -27.407097,...
# 8994   [-7.005243524573524, -9.362865555831435, -12.5...
# 454    [-10.595446780351748, -11.28630359442307, -11....
# 8510   [-16.983994, -15.725474, -14.843489, -14.86797...
# ...                                                  ...
# 9399   [-20.100138845065405, -17.072395799174874, -18...
# 5390   [-23.934858, -20.198006, -19.361034, -21.14603...
# 860    [-42.432987, -42.321323, -41.821438, -41.67199...
# 3619   [-14.775265728007865, -18.70261623150736, -27....
# 11478  [-11.296678767554353, -10.582508383804512, -10...
#
# [18264 rows x 1 columns]

# %%
X_train.iloc[0].astype(f)
# Out:
# feature    [-2.355693042021739, -5.460588114337696, -10.1...
# Name: 11888, dtype: object

# %%
np.mean(X_train, axis=1)
# Out:
# 11888   NaN
# 3336    NaN
# 8994    NaN
# 454     NaN
# 8510    NaN
#          ..
# 9399    NaN
# 5390    NaN
# 860     NaN
# 3619    NaN
# 11478   NaN
# Length: 18264, dtype: float64

# %%
# Data normalization 
mean = np.mean(X_train, axis=0)
std = np.std(X_train, axis=0)

X_train = (X_train - mean)/std
X_test = (X_test - mean)/std

# %%
mean
# Out:
# Series([], dtype: float64)

# %%
std
# Out:
# Series([], dtype: float64)

# %%
X_train
# Out:
#                                                  feature
# 11888  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 3336   [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 8994   [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 454    [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 8510   [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# ...                                                  ...
# 9399   [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 5390   [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 860    [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 3619   [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 11478  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
#
# [18264 rows x 1 columns]

# %%
# Preparation steps to get it into the correct format for Keras 
X_train = np.array(X_train).astype(np.float32)
y_train = np.array(y_train).astype(np.float32)
X_test = np.array(X_test).astype(np.float32)
y_test = np.array(y_test).astype(np.float32)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: only size-1 arrays can be converted to Python scalars
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-d22e8a3f249e> in <module>
#       1 # Preparation steps to get it into the correct format for Keras
# ----> 2 X_train = np.array(X_train).astype(np.float32)
#       3 y_train = np.array(y_train).astype(np.float32)
#       4 X_test = np.array(X_test).astype(np.float32)
#       5 y_test = np.array(y_test).astype(np.float32)
#
# ValueError: setting an array element with a sequence.

# %%
tf.__version__
# Out:
# '2.3.1'

# %%
X_train_tensor = tf.convert_to_tensor(X_train)

print(type(X_train_tensor))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-0162350aa5a0> in <module>
# ----> 1 X_train_tensor = tf.convert_to_tensor(X_train)
#       2
#       3 print(type(X_train_tensor))
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/tensorflow/python/framework/ops.py in convert_to_tensor_v2(value, dtype, dtype_hint, name)
#    1375     ValueError: If the `value` is a tensor not of given `dtype` in graph mode.
#    1376   """
# -> 1377   return convert_to_tensor(
#    1378       value=value,
#    1379       dtype=dtype,
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/tensorflow/python/framework/ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1497
#    1498     if ret is None:
# -> 1499       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1500
#    1501     if ret is NotImplemented:
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/tensorflow/python/framework/tensor_conversion_registry.py in _default_conversion_function(***failed resolving arguments***)
#      50 def _default_conversion_function(value, dtype, name, as_ref):
#      51   del as_ref  # Unused.
# ---> 52   return constant_op.constant(value, dtype, name=name)
#      53
#      54
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/tensorflow/python/framework/constant_op.py in constant(value, dtype, shape, name)
#     261     ValueError: if called on a symbolic tensor.
#     262   """
# --> 263   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     264                         allow_broadcast=True)
#     265
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/tensorflow/python/framework/constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     273       with trace.Trace("tf.constant"):
#     274         return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 275     return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     276
#     277   g = ops.get_default_graph()
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/tensorflow/python/framework/constant_op.py in _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     298 def _constant_eager_impl(ctx, value, dtype, shape, verify_shape):
#     299   """Implementation of eager constant."""
# --> 300   t = convert_to_eager_tensor(value, ctx, dtype)
#     301   if shape is None:
#     302     return t
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#      96       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#      97   ctx.ensure_initialized()
# ---> 98   return ops.EagerTensor(value, ctx.device_name, dtype)
#      99
#     100
#
# ValueError: Failed to convert a NumPy array to a Tensor (Unsupported object type numpy.ndarray).
