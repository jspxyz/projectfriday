# %%
'''
Creating to run Model D Conv1d_mfcc40
different layer system
mfcc 13 avg features
Prediction emotion
Created on 2020.12.11 at 1038

'''
# libraries
import numpy as np
import pandas as pd
import pickle
import seaborn as sns
import tensorflow as tf

from tensorflow.keras.layers import Dense, Dropout, Flatten, Input
from tensorflow.keras.layers import Activation, BatchNormalization
from tensorflow.keras.layers import Conv1D, Conv2D, LSTM
from tensorflow.keras.layers import AveragePooling1D, GlobalAveragePooling2D, MaxPooling1D
from tensorflow.keras.models import Model, model_from_json, Sequential

# added this to plot
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
# load datasets

# assigning the pickle files
with open('./Data_Array_Storage/X_train_mfccavg_axis0_emo.pkl', 'rb') as f:
    X_train = pickle.load(f)

with open('./Data_Array_Storage/X_test_mfccavg_axis0_emo.pkl', 'rb') as f:
    X_test = pickle.load(f)

with open('./Data_Array_Storage/y_train_mfccavg_axis0_emo.pkl', 'rb') as f:
    y_train = pickle.load(f)

with open('./Data_Array_Storage/y_test_mfccavg_axis0_emo.pkl', 'rb') as f:
    y_test = pickle.load(f)
    
print('dataset loaded')
# Out:
# dataset loaded

# %%
# input shape
input_shape = (X_train.shape[1], X_train.shape[2])
print(input_shape)
# Out:
# (216, 1)

# %%
def model_d_conv1d(input_shape):
    model = Sequential()
    model.add(Conv1D(32, 3, padding='same',input_shape=input_shape))  # X_train.shape[1] = No. of Columns (216)
    model.add(Activation('relu'))
    model.add(Conv1D(32, 3, padding='same'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.25))
    model.add(MaxPooling1D(pool_size=(3)))
    model.add(Conv1D(64, 3, padding='same'))
    model.add(Activation('relu'))
    model.add(Conv1D(64, 3, padding='same'))
    model.add(Dropout(0.25))
    model.add(MaxPooling1D(pool_size=(3))) # added drop out and maxpooling layer on 20201209 at 1330
    model.add(Activation('relu'))
    model.add(Conv1D(64, 3, padding='same'))
    model.add(Activation('relu'))
    model.add(Conv1D(64, 3, padding='same'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.25))
    model.add(MaxPooling1D(pool_size=(3)))
    model.add(Conv1D(128, 3, padding='same'))
    model.add(Activation('relu'))
    model.add(Conv1D(128, 3, padding='same'))
    model.add(Activation('relu'))
    model.add(Conv1D(256, 3, padding='same'))
    model.add(Activation('relu'))
#     model.add(LSTM(64))
    model.add(Flatten())
    model.add(Dense(7)) # Target class number
    model.add(Activation('softmax'))
    
    # model optimizer
#     model = model_d_conv1d(input_shape)
    optimizer = tf.keras.optimizers.RMSprop(lr=0.000001, decay=1e-6)
    
    # compile model
    model.compile(loss='categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])

    return model

# %%
def model_d_conv1d_flip(input_shape):
    model = Sequential()
    model.add(Conv1D(256, 3, padding='same',input_shape=input_shape))  # X_train.shape[1] = No. of Columns (216)
    model.add(Activation('relu'))
    model.add(Conv1D(256, 3, padding='same'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.25))
    model.add(MaxPooling1D(pool_size=(3)))
    model.add(Conv1D(128, 3, padding='same'))
    model.add(Activation('relu'))
    model.add(Conv1D(128, 3, padding='same'))
    model.add(Dropout(0.25))
    model.add(MaxPooling1D(pool_size=(3))) # added drop out and maxpooling layer on 20201209 at 1330
    model.add(Activation('relu'))
    model.add(Conv1D(128, 3, padding='same'))
    model.add(Activation('relu'))
    model.add(Conv1D(128, 3, padding='same'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.25))
    model.add(MaxPooling1D(pool_size=(3)))
    model.add(Conv1D(64, 3, padding='same'))
    model.add(Activation('relu'))
    model.add(Conv1D(64, 3, padding='same'))
    model.add(Activation('relu'))
    model.add(Conv1D(32, 3, padding='same'))
    model.add(Activation('relu'))
    model.add(Flatten())
    model.add(Dense(7)) # Target class number
    model.add(Activation('softmax'))
    
    # model optimizer
#     model = model_d_conv1d(input_shape)
    optimizer = tf.keras.optimizers.RMSprop(lr=0.000001, decay=1e-6)
    
    # compile model
    model.compile(loss='categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])

    return model

# %%
# load model and input shape
# from models import model_d_conv1d

# model = model_d_conv1d_flip(input_shape)
model = model_d_conv1d(input_shape)
# optimizer = tf.keras.optimizers.RMSprop(lr=0.000001, decay=1e-6)

print('input shape, model, optimizer loaded')

model.summary()
# Out:
# input shape, model, optimizer loaded
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_18 (Conv1D)           (None, 216, 32)           128
# _________________________________________________________________
# activation_20 (Activation)   (None, 216, 32)           0
# _________________________________________________________________
# conv1d_19 (Conv1D)           (None, 216, 32)           3104
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 216, 32)           128
# _________________________________________________________________
# activation_21 (Activation)   (None, 216, 32)           0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 216, 32)           0
# _________________________________________________________________
# max_pooling1d_6 (MaxPooling1 (None, 72, 32)            0
# _________________________________________________________________
# conv1d_20 (Conv1D)           (None, 72, 64)            6208
# _________________________________________________________________
# activation_22 (Activation)   (None, 72, 64)            0
# _________________________________________________________________
# conv1d_21 (Conv1D)           (None, 72, 64)            12352
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 72, 64)            0
# _________________________________________________________________
# max_pooling1d_7 (MaxPooling1 (None, 24, 64)            0
# _________________________________________________________________
# activation_23 (Activation)   (None, 24, 64)            0
# _________________________________________________________________
# conv1d_22 (Conv1D)           (None, 24, 64)            12352
# _________________________________________________________________
# activation_24 (Activation)   (None, 24, 64)            0
# _________________________________________________________________
# conv1d_23 (Conv1D)           (None, 24, 64)            12352
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 24, 64)            256
# _________________________________________________________________
# activation_25 (Activation)   (None, 24, 64)            0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 24, 64)            0
# _________________________________________________________________
# max_pooling1d_8 (MaxPooling1 (None, 8, 64)             0
# _________________________________________________________________
# conv1d_24 (Conv1D)           (None, 8, 128)            24704
# _________________________________________________________________
# activation_26 (Activation)   (None, 8, 128)            0
# _________________________________________________________________
# conv1d_25 (Conv1D)           (None, 8, 128)            49280
# _________________________________________________________________
# activation_27 (Activation)   (None, 8, 128)            0
# _________________________________________________________________
# conv1d_26 (Conv1D)           (None, 8, 256)            98560
# _________________________________________________________________
# activation_28 (Activation)   (None, 8, 256)            0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 14343
# _________________________________________________________________
# activation_29 (Activation)   (None, 7)                 0
# =================================================================
# Total params: 233,767
# Trainable params: 233,575
# Non-trainable params: 192
# _________________________________________________________________

# %%
# callback list: ModelCheckpoint, reduceLROnPlat, EarlyStopping
# checkpoint_path = "./models_saved/model_d_conv1d_v3.h5"

checkpoint_path = "./models_saved/model_d_conv1d_mfccavg_emo.h5"

# Create a callback that saves the model's weights
callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=False,
                                                 save_best_only=True,
                                                 verbose=1), # 1 tells your which epoch is saving
#                                                  monitor='val_categorical_accuracy',  # added for emo1d
#                                                  mode='max'), # added for emo1d
               tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', # changed from 'val_accuracy', 'val_loss'
                                                patience=5, 
                                                restore_best_weights=True),
#                                                 verbose = 1, # added verbose for emo1d
#                                                 mode = 'min'), # added for emo1d
               tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', 
                                                    patience=2, 
                                                    factor=0.5, 
                                                    min_lr=0.000001, 
                                                    verbose=1)]

print('callbacks and checkpoints set')
# Out:
# callbacks and checkpoints set

# %%
# model.compile(loss='categorical_crossentropy',
#               optimizer=optimizer,
#               metrics=['accuracy'])

# print('model compiled')
# Out:
# model compiled

# %%
batch_size = 64

model_history=model.fit(X_train, 
                        y_train,
                        batch_size=batch_size,
                        epochs=150,
                        validation_data=(X_test, y_test),
                        verbose=2,
                        callbacks=callbacks)
# Out:
# Epoch 1/150
#
# Epoch 00001: val_loss improved from inf to 1.93321, saving model to ./models_saved/model_d_conv1d_mfccavg_emo.h5
# 305/305 - 14s - loss: 1.9602 - accuracy: 0.1611 - val_loss: 1.9332 - val_accuracy: 0.1673
# Epoch 2/150
#
# Epoch 00002: val_loss improved from 1.93321 to 1.91872, saving model to ./models_saved/model_d_conv1d_mfccavg_emo.h5
# 305/305 - 14s - loss: 1.9271 - accuracy: 0.1840 - val_loss: 1.9187 - val_accuracy: 0.1739
# Epoch 3/150
#
# Epoch 00003: val_loss improved from 1.91872 to 1.90730, saving model to ./models_saved/model_d_conv1d_mfccavg_emo.h5
# 305/305 - 13s - loss: 1.9073 - accuracy: 0.2011 - val_loss: 1.9073 - val_accuracy: 0.1926
# Epoch 4/150
#
# Epoch 00004: val_loss improved from 1.90730 to 1.89837, saving model to ./models_saved/model_d_conv1d_mfccavg_emo.h5
# 305/305 - 14s - loss: 1.8917 - accuracy: 0.2149 - val_loss: 1.8984 - val_accuracy: 0.2132
# Epoch 5/150
#
# Epoch 00005: val_loss improved from 1.89837 to 1.88987, saving model to ./models_saved/model_d_conv1d_mfccavg_emo.h5
# 305/305 - 13s - loss: 1.8746 - accuracy: 0.2364 - val_loss: 1.8899 - val_accuracy: 0.2290
# Epoch 6/150
#
# Epoch 00006: val_loss improved from 1.88987 to 1.88186, saving model to ./models_saved/model_d_conv1d_mfccavg_emo.h5
# 305/305 - 13s - loss: 1.8603 - accuracy: 0.2452 - val_loss: 1.8819 - val_accuracy: 0.2421
# Epoch 7/150
#
# Epoch 00007: val_loss improved from 1.88186 to 1.87450, saving model to ./models_saved/model_d_conv1d_mfccavg_emo.h5
# 305/305 - 14s - loss: 1.8492 - accuracy: 0.2538 - val_loss: 1.8745 - val_accuracy: 0.2541
# Epoch 8/150
#
# Epoch 00008: val_loss improved from 1.87450 to 1.86718, saving model to ./models_saved/model_d_conv1d_mfccavg_emo.h5
# 305/305 - 14s - loss: 1.8364 - accuracy: 0.2644 - val_loss: 1.8672 - val_accuracy: 0.2650
# Epoch 9/150
#
# Epoch 00009: val_loss improved from 1.86718 to 1.86007, saving model to ./models_saved/model_d_conv1d_mfccavg_emo.h5
# 305/305 - 17s - loss: 1.8245 - accuracy: 0.2709 - val_loss: 1.8601 - val_accuracy: 0.2769
# Epoch 10/150
#
# Epoch 00010: val_loss improved from 1.86007 to 1.85301, saving model to ./models_saved/model_d_conv1d_mfccavg_emo.h5
# 305/305 - 14s - loss: 1.8137 - accuracy: 0.2751 - val_loss: 1.8530 - val_accuracy: 0.2812
# Epoch 11/150
#
# Epoch 00011: val_loss improved from 1.85301 to 1.84659, saving model to ./models_saved/model_d_conv1d_mfccavg_emo.h5
# 305/305 - 14s - loss: 1.8043 - accuracy: 0.2743 - val_loss: 1.8466 - val_accuracy: 0.2841
# Epoch 12/150
#
# Epoch 00012: val_loss improved from 1.84659 to 1.84022, saving model to ./models_saved/model_d_conv1d_mfccavg_emo.h5
# 305/305 - 15s - loss: 1.7933 - accuracy: 0.2797 - val_loss: 1.8402 - val_accuracy: 0.2892
# Epoch 13/150
#
# Epoch 00013: val_loss improved from 1.84022 to 1.83374, saving model to ./models_saved/model_d_conv1d_mfccavg_emo.h5
# 305/305 - 15s - loss: 1.7854 - accuracy: 0.2824 - val_loss: 1.8337 - val_accuracy: 0.2954
# Epoch 14/150
#
# Epoch 00014: val_loss improved from 1.83374 to 1.82835, saving model to ./models_saved/model_d_conv1d_mfccavg_emo.h5
# 305/305 - 14s - loss: 1.7757 - accuracy: 0.2874 - val_loss: 1.8284 - val_accuracy: 0.2991
# Epoch 15/150
#
# Epoch 00015: val_loss improved from 1.82835 to 1.82276, saving model to ./models_saved/model_d_conv1d_mfccavg_emo.h5
# 305/305 - 14s - loss: 1.7698 - accuracy: 0.2878 - val_loss: 1.8228 - val_accuracy: 0.3009
# Epoch 16/150
#
# Epoch 00016: val_loss improved from 1.82276 to 1.81793, saving model to ./models_saved/model_d_conv1d_mfccavg_emo.h5
# 305/305 - 14s - loss: 1.7637 - accuracy: 0.2915 - val_loss: 1.8179 - val_accuracy: 0.3015
# Epoch 17/150
#
# Epoch 00017: val_loss improved from 1.81793 to 1.81330, saving model to ./models_saved/model_d_conv1d_mfccavg_emo.h5
# 305/305 - 14s - loss: 1.7569 - accuracy: 0.2941 - val_loss: 1.8133 - val_accuracy: 0.3054
# Epoch 18/150
#
# Epoch 00018: val_loss improved from 1.81330 to 1.80917, saving model to ./models_saved/model_d_conv1d_mfccavg_emo.h5
# 305/305 - 15s - loss: 1.7523 - accuracy: 0.2958 - val_loss: 1.8092 - val_accuracy: 0.3059
# Epoch 19/150
#
# Epoch 00019: val_loss improved from 1.80917 to 1.80521, saving model to ./models_saved/model_d_conv1d_mfccavg_emo.h5
# 305/305 - 14s - loss: 1.7485 - accuracy: 0.2973 - val_loss: 1.8052 - val_accuracy: 0.3061
# Epoch 20/150
#
# Epoch 00020: val_loss improved from 1.80521 to 1.80132, saving model to ./models_saved/model_d_conv1d_mfccavg_emo.h5
# 305/305 - 12s - loss: 1.7408 - accuracy: 0.3021 - val_loss: 1.8013 - val_accuracy: 0.3081
# Epoch 21/150
#
# Epoch 00021: val_loss improved from 1.80132 to 1.79788, saving model to ./models_saved/model_d_conv1d_mfccavg_emo.h5
# 305/305 - 11s - loss: 1.7369 - accuracy: 0.3061 - val_loss: 1.7979 - val_accuracy: 0.3094
# Epoch 22/150
#
# Epoch 00022: val_loss improved from 1.79788 to 1.79394, saving model to ./models_saved/model_d_conv1d_mfccavg_emo.h5
# 305/305 - 9s - loss: 1.7332 - accuracy: 0.3022 - val_loss: 1.7939 - val_accuracy: 0.3112
# Epoch 23/150
#
# Epoch 00023: val_loss improved from 1.79394 to 1.79053, saving model to ./models_saved/model_d_conv1d_mfccavg_emo.h5
# 305/305 - 9s - loss: 1.7310 - accuracy: 0.3005 - val_loss: 1.7905 - val_accuracy: 0.3131
# Epoch 24/150
#
# Epoch 00024: val_loss improved from 1.79053 to 1.78824, saving model to ./models_saved/model_d_conv1d_mfccavg_emo.h5
# 305/305 - 10s - loss: 1.7242 - accuracy: 0.3071 - val_loss: 1.7882 - val_accuracy: 0.3135
# Epoch 25/150
#
# Epoch 00025: val_loss improved from 1.78824 to 1.78541, saving model to ./models_saved/model_d_conv1d_mfccavg_emo.h5
# 305/305 - 10s - loss: 1.7252 - accuracy: 0.3088 - val_loss: 1.7854 - val_accuracy: 0.3149
# Epoch 26/150
#
# Epoch 00026: val_loss improved from 1.78541 to 1.78263, saving model to ./models_saved/model_d_conv1d_mfccavg_emo.h5
# 305/305 - 10s - loss: 1.7196 - accuracy: 0.3132 - val_loss: 1.7826 - val_accuracy: 0.3145
# Epoch 27/150
#
# Epoch 00027: val_loss improved from 1.78263 to 1.78012, saving model to ./models_saved/model_d_conv1d_mfccavg_emo.h5
# 305/305 - 9s - loss: 1.7154 - accuracy: 0.3130 - val_loss: 1.7801 - val_accuracy: 0.3180
# Epoch 28/150
#
# Epoch 00028: val_loss improved from 1.78012 to 1.77856, saving model to ./models_saved/model_d_conv1d_mfccavg_emo.h5
# 305/305 - 9s - loss: 1.7128 - accuracy: 0.3111 - val_loss: 1.7786 - val_accuracy: 0.3176
# Epoch 29/150
#
# Epoch 00029: val_loss improved from 1.77856 to 1.77582, saving model to ./models_saved/model_d_conv1d_mfccavg_emo.h5
# 305/305 - 10s - loss: 1.7107 - accuracy: 0.3109 - val_loss: 1.7758 - val_accuracy: 0.3155
# Epoch 30/150
#
# Epoch 00030: val_loss improved from 1.77582 to 1.77391, saving model to ./models_saved/model_d_conv1d_mfccavg_emo.h5
# 305/305 - 10s - loss: 1.7097 - accuracy: 0.3138 - val_loss: 1.7739 - val_accuracy: 0.3159
# Epoch 31/150
#
# Epoch 00031: val_loss improved from 1.77391 to 1.77193, saving model to ./models_saved/model_d_conv1d_mfccavg_emo.h5
# 305/305 - 10s - loss: 1.7046 - accuracy: 0.3167 - val_loss: 1.7719 - val_accuracy: 0.3168
# Epoch 32/150
#
# Epoch 00032: val_loss improved from 1.77193 to 1.76967, saving model to ./models_saved/model_d_conv1d_mfccavg_emo.h5
# 305/305 - 10s - loss: 1.7036 - accuracy: 0.3154 - val_loss: 1.7697 - val_accuracy: 0.3168

# %%
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
score,acc = model.evaluate(X_test, y_test, verbose = 2, batch_size = batch_size)
print("score: %.2f" % (score))
print("acc: %.2f" % (acc))
# Out:
# 77/77 - 0s - loss: 1.7801 - accuracy: 0.3180
# score: 1.78
# acc: 0.32

# %%
# load labels
with open('./Data_Array_Storage/labels_mfccavg_axis0_emo.pkl', 'rb') as f:
    lb = pickle.load(f)

# %%
# error analysis

preds = model.predict(X_test, 
                         batch_size=batch_size, 
                         verbose=1)

preds=preds.argmax(axis=1)
preds
# Out:
# 77/77 [==============================] - 0s 3ms/step
# array([5, 1, 1, ..., 3, 3, 5])

# %%
# predictions 
preds = preds.astype(int).flatten()
preds = (lb.inverse_transform((preds)))
preds = pd.DataFrame({'predictedvalues': preds})

# Actual labels
actual = y_test.argmax(axis=1)
actual = actual.astype(int).flatten()
actual = (lb.inverse_transform((actual)))
actual = pd.DataFrame({'actualvalues': actual})

# Lets combined both of them into a single dataframe
finaldf = actual.join(preds)
finaldf[150:180]
# Out:
#     actualvalues predictedvalues
# 150         fear         neutral
# 151         fear         disgust
# 152     surprise         neutral
# 153         fear             sad
# 154      disgust           angry
# 155        angry            fear
# 156         fear           happy
# 157         fear         disgust
# 158      neutral           happy
# 159        happy            fear
# 160        happy            fear
# 161          sad         disgust
# 162          sad         disgust
# 163      disgust            fear
# 164         fear             sad
# 165        happy           angry
# 166         fear             sad
# 167          sad             sad
# 168        angry             sad
# 169      disgust         disgust
# 170        happy         disgust
# 171      neutral         disgust
# 172        happy         neutral
# 173      disgust           angry
# 174         fear           angry
# 175      disgust         disgust
# 176        angry           angry
# 177      disgust            fear
# 178          sad             sad
# 179        happy         disgust

# %%
# the confusion matrix heat map plot
def print_confusion_matrix(confusion_matrix, class_names, figsize = (10,7), fontsize=14):
    """Prints a confusion matrix, as returned by sklearn.metrics.confusion_matrix, as a heatmap.
    
    Arguments
    ---------
    confusion_matrix: numpy.ndarray
        The numpy.ndarray object returned from a call to sklearn.metrics.confusion_matrix. 
        Similarly constructed ndarrays can also be used.
    class_names: list
        An ordered list of class names, in the order they index the given confusion matrix.
    figsize: tuple
        A 2-long tuple, the first value determining the horizontal size of the ouputted figure,
        the second determining the vertical size. Defaults to (10,7).
    fontsize: int
        Font size for axes labels. Defaults to 14.
        
    Returns
    -------
    matplotlib.figure.Figure
        The resulting confusion matrix figure
    """
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names, columns=class_names, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
        
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
# Get the predictions file 
# finaldf = pd.read_csv("Predictions.csv")
classes = finaldf.actualvalues.unique()
classes.sort()    

# Confusion matrix 
c = confusion_matrix(finaldf.actualvalues, finaldf.predictedvalues)
print(accuracy_score(finaldf.actualvalues, finaldf.predictedvalues))
print_confusion_matrix(c, class_names = classes)
# Out:
# 0.31798561151079136

# %%
# Classification report 
classes = finaldf.actualvalues.unique()
classes.sort()    
print(classification_report(finaldf.actualvalues, finaldf.predictedvalues, target_names=classes))
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.41      0.38      0.39       766
#      disgust       0.30      0.28      0.29       744
#         fear       0.28      0.29      0.29       728
#        happy       0.30      0.30      0.30       751
#      neutral       0.31      0.24      0.27       797
#          sad       0.32      0.52      0.39       799
#     surprise       0.00      0.00      0.00       280
#
#     accuracy                           0.32      4865
#    macro avg       0.27      0.29      0.28      4865
# weighted avg       0.30      0.32      0.30      4865
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
