# %%
'''
Creating to run Model D Conv1d_mfcc40
different layer system
full mfcc features
Created on 2020.12.08 at 1843

'''
# libraries
import numpy as np
import pandas as pd
import pickle
import seaborn as sns
import tensorflow as tf

from tensorflow.keras.layers import Dense, Dropout, Flatten, Input
from tensorflow.keras.layers import Activation, BatchNormalization
from tensorflow.keras.layers import Conv1D, Conv2D, LSTM
from tensorflow.keras.layers import AveragePooling1D, GlobalAveragePooling2D, MaxPooling1D
from tensorflow.keras.models import Model, model_from_json, Sequential

# added this to plot
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
# load datasets

# assigning the pickle files
with open('./Data_Array_Storage/X_train_mfcc40_axis0_emo.pkl', 'rb') as f:
    X_train = pickle.load(f)

with open('./Data_Array_Storage/X_test_mfcc40_axis0_emo.pkl', 'rb') as f:
    X_test = pickle.load(f)

with open('./Data_Array_Storage/y_train_mfcc40_axis0_emo.pkl', 'rb') as f:
    y_train = pickle.load(f)

with open('./Data_Array_Storage/y_test_mfcc40_axis0_emo.pkl', 'rb') as f:
    y_test = pickle.load(f)
    
print('dataset loaded')
# Out:
# dataset loaded

# %%
# input shape
input_shape = (X_train.shape[1], X_train.shape[2])
print(input_shape)
# Out:
# (216, 40)

# %%
import tensorflow_addons
from tensorflow_addons.metrics import F1Score
# model.compile(loss = 'categorical_crossentropy', 
#               optimizer= tf.keras.optimizers.Adam(lr=0.001), 
#               metrics=[tfa.metrics.F1Score(2)])    #'acc'       #weighted_metrics to balance data between 2 classes

# history = model.fit(train_generator,
#                     epochs = 16,
#                     validation_data = val_generator,
#                     callbacks=[cp_callback])

# %%
def model_d_conv1d(input_shape):
    model = Sequential()
    model.add(Conv1D(32, 3, padding='same',input_shape=input_shape))  # X_train.shape[1] = No. of Columns (216)
    model.add(Activation('relu'))
    model.add(Conv1D(32, 3, padding='same'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.25))
    model.add(MaxPooling1D(pool_size=(3)))
    model.add(Conv1D(64, 3, padding='same'))
    model.add(Activation('relu'))
    model.add(Conv1D(64, 3, padding='same'))
    model.add(Dropout(0.25))
    model.add(MaxPooling1D(pool_size=(3))) # added drop out and maxpooling layer on 20201209 at 1330
    model.add(Activation('relu'))
    model.add(Conv1D(64, 3, padding='same'))
    model.add(Activation('relu'))
    model.add(Conv1D(64, 3, padding='same'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.25))
    model.add(MaxPooling1D(pool_size=(3)))
    model.add(Conv1D(128, 3, padding='same'))
    model.add(Activation('relu'))
    model.add(Conv1D(128, 3, padding='same'))
    model.add(Activation('relu'))
    model.add(Conv1D(256, 3, padding='same'))
    model.add(Activation('relu'))
    model.add(LSTM(64))
#     model.add(Flatten())
    model.add(Dense(7)) # Target class number
    model.add(Activation('softmax'))
    
    # model optimizer
#     model = model_d_conv1d(input_shape)
    optimizer = tf.keras.optimizers.RMSprop(lr=0.000001, decay=1e-6)
    
    # compile model
    model.compile(loss='categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])
#               metrics=[tfa.metrics.F1score(7)])
                  
    return model

# %%
def model_d_conv1d_flip(input_shape):
    model = Sequential()
    model.add(Conv1D(256, 3, padding='same',input_shape=input_shape))  # X_train.shape[1] = No. of Columns (216)
    model.add(Activation('relu'))
    model.add(Conv1D(256, 3, padding='same'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.25))
    model.add(MaxPooling1D(pool_size=(3)))
    model.add(Conv1D(128, 3, padding='same'))
    model.add(Activation('relu'))
    model.add(Conv1D(128, 3, padding='same'))
    model.add(Dropout(0.25))
    model.add(MaxPooling1D(pool_size=(3))) # added drop out and maxpooling layer on 20201209 at 1330
    model.add(Activation('relu'))
    model.add(Conv1D(128, 3, padding='same'))
    model.add(Activation('relu'))
    model.add(Conv1D(128, 3, padding='same'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.25))
    model.add(MaxPooling1D(pool_size=(3)))
    model.add(Conv1D(64, 3, padding='same'))
    model.add(Activation('relu'))
    model.add(Conv1D(64, 3, padding='same'))
    model.add(Activation('relu'))
    model.add(Conv1D(32, 3, padding='same'))
    model.add(Activation('relu'))
    model.add(Flatten())
    model.add(Dense(7)) # Target class number
    model.add(Activation('softmax'))
    
    # model optimizer
#     model = model_d_conv1d(input_shape)
    optimizer = tf.keras.optimizers.RMSprop(lr=0.000001, decay=1e-6)
    
    # compile model
    model.compile(loss='categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])

    return model

# %%
# load model and input shape
# from models import model_d_conv1d

# model = model_d_conv1d_flip(input_shape)
model = model_d_conv1d(input_shape)
# optimizer = tf.keras.optimizers.RMSprop(lr=0.000001, decay=1e-6)

print('input shape, model, optimizer loaded')

model.summary()
# Out:
# input shape, model, optimizer loaded
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_45 (Conv1D)           (None, 216, 32)           3872
# _________________________________________________________________
# activation_50 (Activation)   (None, 216, 32)           0
# _________________________________________________________________
# conv1d_46 (Conv1D)           (None, 216, 32)           3104
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 216, 32)           128
# _________________________________________________________________
# activation_51 (Activation)   (None, 216, 32)           0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 216, 32)           0
# _________________________________________________________________
# max_pooling1d_15 (MaxPooling (None, 72, 32)            0
# _________________________________________________________________
# conv1d_47 (Conv1D)           (None, 72, 64)            6208
# _________________________________________________________________
# activation_52 (Activation)   (None, 72, 64)            0
# _________________________________________________________________
# conv1d_48 (Conv1D)           (None, 72, 64)            12352
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 72, 64)            0
# _________________________________________________________________
# max_pooling1d_16 (MaxPooling (None, 24, 64)            0
# _________________________________________________________________
# activation_53 (Activation)   (None, 24, 64)            0
# _________________________________________________________________
# conv1d_49 (Conv1D)           (None, 24, 64)            12352
# _________________________________________________________________
# activation_54 (Activation)   (None, 24, 64)            0
# _________________________________________________________________
# conv1d_50 (Conv1D)           (None, 24, 64)            12352
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 24, 64)            256
# _________________________________________________________________
# activation_55 (Activation)   (None, 24, 64)            0
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 24, 64)            0
# _________________________________________________________________
# max_pooling1d_17 (MaxPooling (None, 8, 64)             0
# _________________________________________________________________
# conv1d_51 (Conv1D)           (None, 8, 128)            24704
# _________________________________________________________________
# activation_56 (Activation)   (None, 8, 128)            0
# _________________________________________________________________
# conv1d_52 (Conv1D)           (None, 8, 128)            49280
# _________________________________________________________________
# activation_57 (Activation)   (None, 8, 128)            0
# _________________________________________________________________
# conv1d_53 (Conv1D)           (None, 8, 256)            98560
# _________________________________________________________________
# activation_58 (Activation)   (None, 8, 256)            0
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 64)                82176
# _________________________________________________________________
# dense_5 (Dense)              (None, 7)                 455
# _________________________________________________________________
# activation_59 (Activation)   (None, 7)                 0
# =================================================================
# Total params: 305,799
# Trainable params: 305,607
# Non-trainable params: 192
# _________________________________________________________________

# %%
# callback list: ModelCheckpoint, reduceLROnPlat, EarlyStopping
# checkpoint_path = "./models_saved/model_d_conv1d_v3.h5"

checkpoint_path = "./models_saved/model_d_conv1d_lstm_emo.h5"

# Create a callback that saves the model's weights
callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=False,
                                                 save_best_only=True,
                                                 verbose=1), # 1 tells your which epoch is saving
#                                                  monitor='val_categorical_accuracy',  # added for emo1d
#                                                  mode='max'), # added for emo1d
               tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', # changed from 'val_accuracy', 'val_loss'
                                                patience=5, 
                                                restore_best_weights=True),
#                                                 verbose = 1, # added verbose for emo1d
#                                                 mode = 'min'), # added for emo1d
               tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', 
                                                    patience=2, 
                                                    factor=0.5, 
                                                    min_lr=0.000001, 
                                                    verbose=1)]

print('callbacks and checkpoints set')
# Out:
# callbacks and checkpoints set

# %%
# model.compile(loss='categorical_crossentropy',
#               optimizer=optimizer,
#               metrics=['accuracy'])

# print('model compiled')
# Out:
# model compiled

# %%
batch_size = 32

model_history=model.fit(X_train, 
                        y_train,
                        batch_size=batch_size,
                        epochs=150,
                        validation_data=(X_test, y_test),
                        verbose=2,
                        callbacks=callbacks)
# Out:
# Epoch 1/150
#
# Epoch 00001: val_loss improved from inf to 1.93891, saving model to ./models_saved/model_d_conv1d_lstm_emo.h5
# 609/609 - 15s - loss: 1.9612 - accuracy: 0.1512 - val_loss: 1.9389 - val_accuracy: 0.1496
# Epoch 2/150
#
# Epoch 00002: val_loss improved from 1.93891 to 1.92340, saving model to ./models_saved/model_d_conv1d_lstm_emo.h5
# 609/609 - 15s - loss: 1.9245 - accuracy: 0.1512 - val_loss: 1.9234 - val_accuracy: 0.1470
# Epoch 3/150
#
# Epoch 00003: val_loss improved from 1.92340 to 1.91460, saving model to ./models_saved/model_d_conv1d_lstm_emo.h5
# 609/609 - 15s - loss: 1.9091 - accuracy: 0.1663 - val_loss: 1.9146 - val_accuracy: 0.1494
# Epoch 4/150
#
# Epoch 00004: val_loss improved from 1.91460 to 1.90880, saving model to ./models_saved/model_d_conv1d_lstm_emo.h5
# 609/609 - 15s - loss: 1.8999 - accuracy: 0.1944 - val_loss: 1.9088 - val_accuracy: 0.1764
# Epoch 5/150
#
# Epoch 00005: val_loss improved from 1.90880 to 1.90367, saving model to ./models_saved/model_d_conv1d_lstm_emo.h5
# 609/609 - 14s - loss: 1.8928 - accuracy: 0.2134 - val_loss: 1.9037 - val_accuracy: 0.1984
# Epoch 6/150
#
# Epoch 00006: val_loss improved from 1.90367 to 1.89984, saving model to ./models_saved/model_d_conv1d_lstm_emo.h5
# 609/609 - 15s - loss: 1.8872 - accuracy: 0.2196 - val_loss: 1.8998 - val_accuracy: 0.2068
# Epoch 7/150
#
# Epoch 00007: val_loss improved from 1.89984 to 1.89618, saving model to ./models_saved/model_d_conv1d_lstm_emo.h5
# 609/609 - 17s - loss: 1.8816 - accuracy: 0.2216 - val_loss: 1.8962 - val_accuracy: 0.2125
# Epoch 8/150
#
# Epoch 00008: val_loss improved from 1.89618 to 1.89247, saving model to ./models_saved/model_d_conv1d_lstm_emo.h5
# 609/609 - 19s - loss: 1.8756 - accuracy: 0.2273 - val_loss: 1.8925 - val_accuracy: 0.2113
# Epoch 9/150
#
# Epoch 00009: val_loss improved from 1.89247 to 1.88871, saving model to ./models_saved/model_d_conv1d_lstm_emo.h5
# 609/609 - 19s - loss: 1.8699 - accuracy: 0.2284 - val_loss: 1.8887 - val_accuracy: 0.2127
# Epoch 10/150
#
# Epoch 00010: val_loss improved from 1.88871 to 1.88480, saving model to ./models_saved/model_d_conv1d_lstm_emo.h5
# 609/609 - 18s - loss: 1.8636 - accuracy: 0.2272 - val_loss: 1.8848 - val_accuracy: 0.2142
# Epoch 11/150
#
# Epoch 00011: val_loss improved from 1.88480 to 1.88057, saving model to ./models_saved/model_d_conv1d_lstm_emo.h5
# 609/609 - 18s - loss: 1.8559 - accuracy: 0.2323 - val_loss: 1.8806 - val_accuracy: 0.2171
# Epoch 12/150
#
# Epoch 00012: val_loss improved from 1.88057 to 1.87499, saving model to ./models_saved/model_d_conv1d_lstm_emo.h5
# 609/609 - 18s - loss: 1.8474 - accuracy: 0.2348 - val_loss: 1.8750 - val_accuracy: 0.2220
# Epoch 13/150
#
# Epoch 00013: val_loss improved from 1.87499 to 1.86995, saving model to ./models_saved/model_d_conv1d_lstm_emo.h5
# 609/609 - 18s - loss: 1.8379 - accuracy: 0.2409 - val_loss: 1.8700 - val_accuracy: 0.2212
# Epoch 14/150
#
# Epoch 00014: val_loss improved from 1.86995 to 1.86340, saving model to ./models_saved/model_d_conv1d_lstm_emo.h5
# 609/609 - 14s - loss: 1.8277 - accuracy: 0.2478 - val_loss: 1.8634 - val_accuracy: 0.2255
# Epoch 15/150
#
# Epoch 00015: val_loss improved from 1.86340 to 1.85476, saving model to ./models_saved/model_d_conv1d_lstm_emo.h5
# 609/609 - 13s - loss: 1.8161 - accuracy: 0.2530 - val_loss: 1.8548 - val_accuracy: 0.2282
# Epoch 16/150
#
# Epoch 00016: val_loss improved from 1.85476 to 1.84824, saving model to ./models_saved/model_d_conv1d_lstm_emo.h5
# 609/609 - 14s - loss: 1.8039 - accuracy: 0.2601 - val_loss: 1.8482 - val_accuracy: 0.2282
# Epoch 17/150
#
# Epoch 00017: val_loss improved from 1.84824 to 1.84120, saving model to ./models_saved/model_d_conv1d_lstm_emo.h5
# 609/609 - 13s - loss: 1.7894 - accuracy: 0.2658 - val_loss: 1.8412 - val_accuracy: 0.2302
# Epoch 18/150
#
# Epoch 00018: val_loss improved from 1.84120 to 1.83393, saving model to ./models_saved/model_d_conv1d_lstm_emo.h5
# 609/609 - 13s - loss: 1.7752 - accuracy: 0.2798 - val_loss: 1.8339 - val_accuracy: 0.2356
# Epoch 19/150
#
# Epoch 00019: val_loss improved from 1.83393 to 1.82256, saving model to ./models_saved/model_d_conv1d_lstm_emo.h5
# 609/609 - 13s - loss: 1.7586 - accuracy: 0.2863 - val_loss: 1.8226 - val_accuracy: 0.2444
# Epoch 20/150
#
# Epoch 00020: val_loss improved from 1.82256 to 1.81416, saving model to ./models_saved/model_d_conv1d_lstm_emo.h5
# 609/609 - 13s - loss: 1.7421 - accuracy: 0.2961 - val_loss: 1.8142 - val_accuracy: 0.2493
# Epoch 21/150
#
# Epoch 00021: val_loss improved from 1.81416 to 1.80493, saving model to ./models_saved/model_d_conv1d_lstm_emo.h5
# 609/609 - 13s - loss: 1.7256 - accuracy: 0.3026 - val_loss: 1.8049 - val_accuracy: 0.2539
# Epoch 22/150
#
# Epoch 00022: val_loss improved from 1.80493 to 1.79477, saving model to ./models_saved/model_d_conv1d_lstm_emo.h5
# 609/609 - 13s - loss: 1.7095 - accuracy: 0.3138 - val_loss: 1.7948 - val_accuracy: 0.2617
# Epoch 23/150
#
# Epoch 00023: val_loss improved from 1.79477 to 1.78850, saving model to ./models_saved/model_d_conv1d_lstm_emo.h5
# 609/609 - 14s - loss: 1.6945 - accuracy: 0.3207 - val_loss: 1.7885 - val_accuracy: 0.2666
# Epoch 24/150
#
# Epoch 00024: val_loss improved from 1.78850 to 1.77883, saving model to ./models_saved/model_d_conv1d_lstm_emo.h5
# 609/609 - 14s - loss: 1.6786 - accuracy: 0.3280 - val_loss: 1.7788 - val_accuracy: 0.2740
# Epoch 25/150
#
# Epoch 00025: val_loss improved from 1.77883 to 1.77204, saving model to ./models_saved/model_d_conv1d_lstm_emo.h5
# 609/609 - 14s - loss: 1.6659 - accuracy: 0.3307 - val_loss: 1.7720 - val_accuracy: 0.2758
# Epoch 26/150
#
# Epoch 00026: val_loss improved from 1.77204 to 1.76673, saving model to ./models_saved/model_d_conv1d_lstm_emo.h5
# 609/609 - 14s - loss: 1.6529 - accuracy: 0.3392 - val_loss: 1.7667 - val_accuracy: 0.2828
# Epoch 27/150
#
# Epoch 00027: val_loss improved from 1.76673 to 1.76041, saving model to ./models_saved/model_d_conv1d_lstm_emo.h5
# 609/609 - 14s - loss: 1.6416 - accuracy: 0.3387 - val_loss: 1.7604 - val_accuracy: 0.2853
# Epoch 28/150
#
# Epoch 00028: val_loss improved from 1.76041 to 1.75776, saving model to ./models_saved/model_d_conv1d_lstm_emo.h5
# 609/609 - 14s - loss: 1.6313 - accuracy: 0.3469 - val_loss: 1.7578 - val_accuracy: 0.2865
# Epoch 29/150
#
# Epoch 00029: val_loss improved from 1.75776 to 1.75367, saving model to ./models_saved/model_d_conv1d_lstm_emo.h5
# 609/609 - 14s - loss: 1.6179 - accuracy: 0.3537 - val_loss: 1.7537 - val_accuracy: 0.2886
# Epoch 30/150
#
# Epoch 00030: val_loss improved from 1.75367 to 1.74892, saving model to ./models_saved/model_d_conv1d_lstm_emo.h5
# 609/609 - 14s - loss: 1.6108 - accuracy: 0.3530 - val_loss: 1.7489 - val_accuracy: 0.2900
# Epoch 31/150
#
# Epoch 00031: val_loss improved from 1.74892 to 1.74576, saving model to ./models_saved/model_d_conv1d_lstm_emo.h5
# 609/609 - 14s - loss: 1.5988 - accuracy: 0.3613 - val_loss: 1.7458 - val_accuracy: 0.2923
# Epoch 32/150
#
# Epoch 00032: val_loss improved from 1.74576 to 1.74242, saving model to ./models_saved/model_d_conv1d_lstm_emo.h5
# 609/609 - 14s - loss: 1.5932 - accuracy: 0.3627 - val_loss: 1.7424 - val_accuracy: 0.2911
# Epoch 33/150
#
# Epoch 00033: val_loss did not improve from 1.74242
# 609/609 - 14s - loss: 1.5835 - accuracy: 0.3719 - val_loss: 1.7426 - val_accuracy: 0.2878
# Epoch 34/150
#
# Epoch 00034: val_loss improved from 1.74242 to 1.73911, saving model to ./models_saved/model_d_conv1d_lstm_emo.h5
# 609/609 - 15s - loss: 1.5740 - accuracy: 0.3755 - val_loss: 1.7391 - val_accuracy: 0.2869
# Epoch 35/150
#
# Epoch 00035: val_loss improved from 1.73911 to 1.73579, saving model to ./models_saved/model_d_conv1d_lstm_emo.h5
# 609/609 - 15s - loss: 1.5671 - accuracy: 0.3723 - val_loss: 1.7358 - val_accuracy: 0.2906
# Epoch 36/150
#
# Epoch 00036: val_loss improved from 1.73579 to 1.73146, saving model to ./models_saved/model_d_conv1d_lstm_emo.h5
# 609/609 - 14s - loss: 1.5596 - accuracy: 0.3810 - val_loss: 1.7315 - val_accuracy: 0.2892

# %%
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
score,acc = model.evaluate(X_test, y_test, verbose = 2, batch_size = batch_size)
print("score: %.2f" % (score))
print("acc: %.2f" % (acc))
# Out:
# 153/153 - 1s - loss: 1.7458 - accuracy: 0.2923
# score: 1.75
# acc: 0.29

# %%
# load labels
with open('./Data_Array_Storage/labels_emo.pkl', 'rb') as f:
    lb = pickle.load(f)

# %%
# error analysis

preds = model.predict(X_test, 
                         batch_size=batch_size, 
                         verbose=1)

preds=preds.argmax(axis=1)
preds
# Out:
# 153/153 [==============================] - 1s 4ms/step
# array([5, 4, 5, ..., 0, 4, 5])

# %%
# predictions 
preds = preds.astype(int).flatten()
preds = (lb.inverse_transform((preds)))
preds = pd.DataFrame({'predictedvalues': preds})

# Actual labels
actual = y_test.argmax(axis=1)
actual = actual.astype(int).flatten()
actual = (lb.inverse_transform((actual)))
actual = pd.DataFrame({'actualvalues': actual})

# Lets combined both of them into a single dataframe
finaldf = actual.join(preds)
finaldf[150:180]
# Out:
#     actualvalues predictedvalues
# 150          sad             sad
# 151      disgust             sad
# 152        angry         neutral
# 153      disgust             sad
# 154      neutral             sad
# 155      disgust           happy
# 156      disgust         neutral
# 157         fear             sad
# 158        angry           happy
# 159      disgust             sad
# 160         fear             sad
# 161         fear             sad
# 162         fear           angry
# 163         fear           happy
# 164        angry             sad
# 165      disgust             sad
# 166      disgust             sad
# 167      neutral             sad
# 168      neutral         neutral
# 169      disgust             sad
# 170      neutral             sad
# 171      neutral             sad
# 172      neutral         neutral
# 173        angry             sad
# 174        angry         disgust
# 175      disgust             sad
# 176      neutral             sad
# 177     surprise           happy
# 178         fear           happy
# 179      neutral         neutral

# %%
# the confusion matrix heat map plot
def print_confusion_matrix(confusion_matrix, class_names, figsize = (10,7), fontsize=14):
    """Prints a confusion matrix, as returned by sklearn.metrics.confusion_matrix, as a heatmap.
    
    Arguments
    ---------
    confusion_matrix: numpy.ndarray
        The numpy.ndarray object returned from a call to sklearn.metrics.confusion_matrix. 
        Similarly constructed ndarrays can also be used.
    class_names: list
        An ordered list of class names, in the order they index the given confusion matrix.
    figsize: tuple
        A 2-long tuple, the first value determining the horizontal size of the ouputted figure,
        the second determining the vertical size. Defaults to (10,7).
    fontsize: int
        Font size for axes labels. Defaults to 14.
        
    Returns
    -------
    matplotlib.figure.Figure
        The resulting confusion matrix figure
    """
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names, columns=class_names, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
        
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
# Get the predictions file 
# finaldf = pd.read_csv("Predictions.csv")
classes = finaldf.actualvalues.unique()
classes.sort()    

# Confusion matrix 
c = confusion_matrix(finaldf.actualvalues, finaldf.predictedvalues)
print(accuracy_score(finaldf.actualvalues, finaldf.predictedvalues))
print_confusion_matrix(c, class_names = classes)
# Out:
# 0.2922918807810894

# %%
# Classification report 
classes = finaldf.actualvalues.unique()
classes.sort()    
print(classification_report(finaldf.actualvalues, finaldf.predictedvalues, target_names=classes))
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.50      0.21      0.29       771
#      disgust       0.31      0.07      0.12       808
#         fear       0.27      0.12      0.17       751
#        happy       0.29      0.34      0.31       785
#      neutral       0.24      0.30      0.26       748
#          sad       0.29      0.85      0.43       740
#     surprise       0.00      0.00      0.00       262
#
#     accuracy                           0.29      4865
#    macro avg       0.27      0.27      0.23      4865
# weighted avg       0.30      0.29      0.25      4865
